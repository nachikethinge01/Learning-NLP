# %% [markdown]
# ## 1. Darwin's bibliography
# <p><img src="https://assets.datacamp.com/production/project_607/img/CharlesDarwin.jpg" alt="Charles Darwin" width="300px"></p>
# <p>Charles Darwin is one of the few universal figures of science. His most renowned work is without a doubt his "<em>On the Origin of Species</em>" published in 1859 which introduced the concept of natural selection. But Darwin wrote many other books on a wide range of topics, including geology, plants or his personal life. In this notebook, we will automatically detect how closely related his books are to each other.</p>
# <p>To this purpose, we will develop the bases of <strong>a content-based book recommendation system</strong>, which will determine which books are close to each other based on how similar the discussed topics are. The methods we will use are commonly used in text- or documents-heavy industries such as legal, tech or customer support to perform some common task such as text classification or handling search engine queries.</p>
# <p>Let's take a look at the books we'll use in our recommendation system.</p>

# %%
# Import library
import glob

# The books files are contained in this folder
folder = "datasets/"

# List all the .txt files and sort them alphabetically
files = glob.glob(folder + "*txt")
# ... YOUR CODE FOR TASK 1 ...
files.sort()
files
# Out:
# ['datasets/Autobiography.txt',
#  'datasets/CoralReefs.txt',
#  'datasets/DescentofMan.txt',
#  'datasets/DifferentFormsofFlowers.txt',
#  'datasets/EffectsCrossSelfFertilization.txt',
#  'datasets/ExpressionofEmotionManAnimals.txt',
#  'datasets/FormationVegetableMould.txt',
#  'datasets/FoundationsOriginofSpecies.txt',
#  'datasets/GeologicalObservationsSouthAmerica.txt',
#  'datasets/InsectivorousPlants.txt',
#  'datasets/LifeandLettersVol1.txt',
#  'datasets/LifeandLettersVol2.txt',
#  'datasets/MonographCirripedia.txt',
#  'datasets/MonographCirripediaVol2.txt',
#  'datasets/MovementClimbingPlants.txt',
#  'datasets/OriginofSpecies.txt',
#  'datasets/PowerMovementPlants.txt',
#  'datasets/VariationPlantsAnimalsDomestication.txt',
#  'datasets/VolcanicIslands.txt',
#  'datasets/VoyageBeagle.txt']

# %% [markdown]
# ## 2. Load the contents of each book into Python
# <p>As a first step, we need to load the content of these books into Python and do some basic pre-processing to facilitate the downstream analyses. We call such a collection of texts <strong>a corpus</strong>. We will also store the titles for these books for future reference and print their respective length to get a gauge for their contents.</p>

# %%
# Import libraries
import re, os

# Initialize the object that will contain the texts and titles
txts = []
titles = []

for n in files:
    # Open each file
    f = open(n, encoding='utf-8-sig')
    # Remove all non-alpha-numeric characters
    # ... YOUR CODE FOR TASK 2 ...
    data = re.sub('[\W_]+', ' ', f.read())
    # Store the texts and titles of the books in two separate lists
    txts.append(data)
    titles.append(os.path.basename(n).replace(".txt", ""))

# Print the length, in characters, of each book
[len(t) for t in txts]
# Out:
# [123231,
#  496068,
#  1776539,
#  617088,
#  913713,
#  624232,
#  335920,
#  523021,
#  797401,
#  901406,
#  1047518,
#  1010643,
#  767492,
#  1660866,
#  298319,
#  916267,
#  1093567,
#  1043499,
#  341447,
#  1149574]

# %% [markdown]
# ## 3. Find "On the Origin of Species"
# <p>For the next parts of this analysis, we will often check the results returned by our method for a given book. For consistency, we will refer to Darwin's most famous book: "<em>On the Origin of Species</em>." Let's find to which index this book is associated.</p>

# %%
# Browse the list containing all the titles
ori = -1
for i in range(len(titles)):
    # Store the index if the title is "OriginofSpecies"
    # ... YOUR CODE FOR TASK 3 ...
    if titles[i] == "OriginofSpecies":
        ori = i
        break

# Print the stored index
# ... YOUR CODE FOR TASK 3 ...
print(ori)
# Out:
# 15

# %% [markdown]
# ## 4. Tokenize the corpus
# <p>As a next step, we need to transform the corpus into a format that is easier to deal with for the downstream analyses. We will tokenize our corpus, i.e., transform each text into a list of the individual words (called tokens) it is made of. To check the output of our process, we will print the first 20 tokens of "<em>On the Origin of Species</em>".</p>

# %%
# Define a list of stop words
stoplist = set('for a of the and to in to be which some is at that we i who whom show via may my our might as well'.split())

# Convert the text to lower case 
txts_lower_case = [text.lower() for text in txts]


# Transform the text into tokens 
txts_split = [text.split() for text in txts_lower_case]

# Remove tokens which are part of the list of stop words
texts = [[word for word in text if word not in stoplist] for text in txts_split]
# Print the first 20 tokens for the "On the Origin of Species" book
texts[0:20]
# Out:
# [['autobiography',
#   'charles',
#   'darwin',
#   'from',
#   'life',
#   'letters',
#   'charles',
#   'darwin',
#   'by',
#   'charles',
#   'darwin',
#   'edited',
#   'by',
#   'his',
#   'son',
#   'francis',
#   'darwin',
#   'father',
#   's',
#   'autobiographical',
#   'recollections',
#   'given',
#   'present',
#   'chapter',
#   'were',
#   'written',
#   'his',
#   'children',
#   'written',
#   'without',
#   'any',
#   'thought',
#   'they',
#   'would',
#   'ever',
#   'published',
#   'many',
#   'this',
#   'seem',
#   'an',
#   'impossibility',
#   'but',
#   'those',
#   'knew',
#   'father',
#   'will',
#   'understand',
#   'how',
#   'it',
#   'was',
#   'not',
#   'only',
#   'possible',
#   'but',
#   'natural',
#   'autobiography',
#   'bears',
#   'heading',
#   'recollections',
#   'development',
#   'mind',
#   'character',
#   'end',
#   'with',
#   'following',
#   'note',
#   'aug',
#   '3',
#   '1876',
#   'this',
#   'sketch',
#   'life',
#   'was',
#   'begun',
#   'about',
#   '28th',
#   'hopedene',
#   'mr',
#   'hensleigh',
#   'wedgwood',
#   's',
#   'house',
#   'surrey',
#   'since',
#   'then',
#   'have',
#   'written',
#   'nearly',
#   'an',
#   'hour',
#   'on',
#   'most',
#   'afternoons',
#   'it',
#   'will',
#   'easily',
#   'understood',
#   'narrative',
#   'personal',
#   'intimate',
#   'kind',
#   'written',
#   'his',
#   'wife',
#   'children',
#   'passages',
#   'should',
#   'occur',
#   'must',
#   'here',
#   'omitted',
#   'have',
#   'not',
#   'thought',
#   'it',
#   'necessary',
#   'indicate',
#   'where',
#   'such',
#   'omissions',
#   'are',
#   'made',
#   'it',
#   'has',
#   'been',
#   'found',
#   'necessary',
#   'make',
#   'few',
#   'corrections',
#   'obvious',
#   'verbal',
#   'slips',
#   'but',
#   'number',
#   'such',
#   'alterations',
#   'has',
#   'been',
#   'kept',
#   'down',
#   'minimum',
#   'f',
#   'd',
#   'german',
#   'editor',
#   'having',
#   'written',
#   'me',
#   'an',
#   'account',
#   'development',
#   'mind',
#   'character',
#   'with',
#   'sketch',
#   'autobiography',
#   'have',
#   'thought',
#   'attempt',
#   'would',
#   'amuse',
#   'me',
#   'possibly',
#   'interest',
#   'children',
#   'or',
#   'their',
#   'children',
#   'know',
#   'it',
#   'would',
#   'have',
#   'interested',
#   'me',
#   'greatly',
#   'have',
#   'read',
#   'even',
#   'so',
#   'short',
#   'dull',
#   'sketch',
#   'mind',
#   'grandfather',
#   'written',
#   'by',
#   'himself',
#   'what',
#   'he',
#   'thought',
#   'did',
#   'how',
#   'he',
#   'worked',
#   'have',
#   'attempted',
#   'write',
#   'following',
#   'account',
#   'myself',
#   'if',
#   'were',
#   'dead',
#   'man',
#   'another',
#   'world',
#   'looking',
#   'back',
#   'own',
#   'life',
#   'nor',
#   'have',
#   'found',
#   'this',
#   'difficult',
#   'life',
#   'nearly',
#   'over',
#   'with',
#   'me',
#   'have',
#   'taken',
#   'no',
#   'pains',
#   'about',
#   'style',
#   'writing',
#   'was',
#   'born',
#   'shrewsbury',
#   'on',
#   'february',
#   '12th',
#   '1809',
#   'earliest',
#   'recollection',
#   'goes',
#   'back',
#   'only',
#   'when',
#   'was',
#   'few',
#   'months',
#   'over',
#   'four',
#   'years',
#   'old',
#   'when',
#   'went',
#   'near',
#   'abergele',
#   'sea',
#   'bathing',
#   'recollect',
#   'events',
#   'places',
#   'there',
#   'with',
#   'little',
#   'distinctness',
#   'mother',
#   'died',
#   'july',
#   '1817',
#   'when',
#   'was',
#   'little',
#   'over',
#   'eight',
#   'years',
#   'old',
#   'it',
#   'odd',
#   'can',
#   'remember',
#   'hardly',
#   'anything',
#   'about',
#   'her',
#   'except',
#   'her',
#   'death',
#   'bed',
#   'her',
#   'black',
#   'velvet',
#   'gown',
#   'her',
#   'curiously',
#   'constructed',
#   'work',
#   'table',
#   'spring',
#   'this',
#   'same',
#   'year',
#   'was',
#   'sent',
#   'day',
#   'school',
#   'shrewsbury',
#   'where',
#   'stayed',
#   'year',
#   'have',
#   'been',
#   'told',
#   'was',
#   'much',
#   'slower',
#   'learning',
#   'than',
#   'younger',
#   'sister',
#   'catherine',
#   'believe',
#   'was',
#   'many',
#   'ways',
#   'naughty',
#   'boy',
#   'by',
#   'time',
#   'went',
#   'this',
#   'day',
#   'school',
#   'kept',
#   'by',
#   'rev',
#   'g',
#   'case',
#   'minister',
#   'unitarian',
#   'chapel',
#   'high',
#   'street',
#   'mrs',
#   'darwin',
#   'was',
#   'unitarian',
#   'attended',
#   'mr',
#   'case',
#   's',
#   'chapel',
#   'father',
#   'little',
#   'boy',
#   'went',
#   'there',
#   'with',
#   'his',
#   'elder',
#   'sisters',
#   'but',
#   'both',
#   'he',
#   'his',
#   'brother',
#   'were',
#   'christened',
#   'intended',
#   'belong',
#   'church',
#   'england',
#   'after',
#   'his',
#   'early',
#   'boyhood',
#   'he',
#   'seems',
#   'usually',
#   'have',
#   'gone',
#   'church',
#   'not',
#   'mr',
#   'case',
#   's',
#   'it',
#   'appears',
#   'st',
#   'james',
#   'gazette',
#   'dec',
#   '15',
#   '1883',
#   'mural',
#   'tablet',
#   'has',
#   'been',
#   'erected',
#   'his',
#   'memory',
#   'chapel',
#   'now',
#   'known',
#   'free',
#   'christian',
#   'church',
#   'taste',
#   'natural',
#   'history',
#   'more',
#   'especially',
#   'collecting',
#   'was',
#   'developed',
#   'tried',
#   'make',
#   'out',
#   'names',
#   'plants',
#   'rev',
#   'w',
#   'leighton',
#   'was',
#   'schoolfellow',
#   'father',
#   's',
#   'mr',
#   'case',
#   's',
#   'school',
#   'remembers',
#   'his',
#   'bringing',
#   'flower',
#   'school',
#   'saying',
#   'his',
#   'mother',
#   'had',
#   'taught',
#   'him',
#   'how',
#   'by',
#   'looking',
#   'inside',
#   'blossom',
#   'name',
#   'plant',
#   'could',
#   'discovered',
#   'mr',
#   'leighton',
#   'goes',
#   'on',
#   'this',
#   'greatly',
#   'roused',
#   'attention',
#   'curiosity',
#   'enquired',
#   'him',
#   'repeatedly',
#   'how',
#   'this',
#   'could',
#   'done',
#   'but',
#   'his',
#   'lesson',
#   'was',
#   'naturally',
#   'enough',
#   'not',
#   'transmissible',
#   'f',
#   'd',
#   'collected',
#   'all',
#   'sorts',
#   'things',
#   'shells',
#   'seals',
#   'franks',
#   'coins',
#   'minerals',
#   'passion',
#   'collecting',
#   'leads',
#   'man',
#   'systematic',
#   'naturalist',
#   'virtuoso',
#   'or',
#   'miser',
#   'was',
#   'very',
#   'strong',
#   'me',
#   'was',
#   'clearly',
#   'innate',
#   'none',
#   'sisters',
#   'or',
#   'brother',
#   'ever',
#   'had',
#   'this',
#   'taste',
#   'one',
#   'little',
#   'event',
#   'during',
#   'this',
#   'year',
#   'has',
#   'fixed',
#   'itself',
#   'very',
#   'firmly',
#   'mind',
#   'hope',
#   'it',
#   'has',
#   'done',
#   'so',
#   'from',
#   'conscience',
#   'having',
#   'been',
#   'afterwards',
#   'sorely',
#   'troubled',
#   'by',
#   'it',
#   'it',
#   'curious',
#   'showing',
#   'apparently',
#   'was',
#   'interested',
#   'this',
#   'early',
#   'age',
#   'variability',
#   'plants',
#   'told',
#   'another',
#   'little',
#   'boy',
#   'believe',
#   'it',
#   'was',
#   'leighton',
#   'afterwards',
#   'became',
#   'known',
#   'lichenologist',
#   'botanist',
#   'could',
#   'produce',
#   'variously',
#   'coloured',
#   'polyanthuses',
#   'primroses',
#   'by',
#   'watering',
#   'them',
#   'with',
#   'certain',
#   'coloured',
#   'fluids',
#   'was',
#   'course',
#   'monstrous',
#   'fable',
#   'had',
#   'never',
#   'been',
#   'tried',
#   'by',
#   'me',
#   'here',
#   'also',
#   'confess',
#   'little',
#   'boy',
#   'was',
#   'much',
#   'given',
#   'inventing',
#   'deliberate',
#   'falsehoods',
#   'this',
#   'was',
#   'always',
#   'done',
#   'sake',
#   'causing',
#   'excitement',
#   'instance',
#   'once',
#   'gathered',
#   'much',
#   'valuable',
#   'fruit',
#   'from',
#   'father',
#   's',
#   'trees',
#   'hid',
#   'it',
#   'shrubbery',
#   'then',
#   'ran',
#   'breathless',
#   'haste',
#   'spread',
#   'news',
#   'had',
#   'discovered',
#   'hoard',
#   'stolen',
#   'fruit',
#   'must',
#   'have',
#   'been',
#   'very',
#   'simple',
#   'little',
#   'fellow',
#   'when',
#   'first',
#   'went',
#   'school',
#   'boy',
#   'name',
#   'garnett',
#   'took',
#   'me',
#   'into',
#   'cake',
#   'shop',
#   'one',
#   'day',
#   'bought',
#   'cakes',
#   'he',
#   'did',
#   'not',
#   'pay',
#   'shopman',
#   'trusted',
#   'him',
#   'when',
#   'came',
#   'out',
#   'asked',
#   'him',
#   'why',
#   'he',
#   'did',
#   'not',
#   'pay',
#   'them',
#   'he',
#   'instantly',
#   'answered',
#   'why',
#   'do',
#   'you',
#   'not',
#   'know',
#   'uncle',
#   'left',
#   'great',
#   'sum',
#   'money',
#   'town',
#   'on',
#   'condition',
#   'every',
#   'tradesman',
#   'should',
#   'give',
#   'whatever',
#   'was',
#   'wanted',
#   'without',
#   'payment',
#   'any',
#   'one',
#   'wore',
#   'his',
#   'old',
#   'hat',
#   'moved',
#   'it',
#   'particular',
#   'manner',
#   'he',
#   'then',
#   'showed',
#   'me',
#   'how',
#   'it',
#   'was',
#   'moved',
#   'he',
#   'then',
#   'went',
#   'into',
#   'another',
#   'shop',
#   'where',
#   'he',
#   'was',
#   'trusted',
#   'asked',
#   'small',
#   'article',
#   'moving',
#   'his',
#   'hat',
#   'proper',
#   'manner',
#   'course',
#   'obtained',
#   'it',
#   'without',
#   'payment',
#   'when',
#   'came',
#   'out',
#   'he',
#   'said',
#   'now',
#   'if',
#   'you',
#   'like',
#   'go',
#   'by',
#   'yourself',
#   'into',
#   'cake',
#   'shop',
#   'how',
#   'remember',
#   'its',
#   'exact',
#   'position',
#   'will',
#   'lend',
#   'you',
#   'hat',
#   'you',
#   'can',
#   'get',
#   'whatever',
#   'you',
#   'like',
#   'if',
#   'you',
#   'move',
#   'hat',
#   'on',
#   'your',
#   'head',
#   'properly',
#   'gladly',
#   'accepted',
#   'generous',
#   'offer',
#   'went',
#   'asked',
#   'cakes',
#   'moved',
#   'old',
#   'hat',
#   'was',
#   'walking',
#   'out',
#   'shop',
#   'when',
#   'shopman',
#   'made',
#   'rush',
#   'me',
#   'so',
#   'dropped',
#   'cakes',
#   'ran',
#   'dear',
#   'life',
#   'was',
#   'astonished',
#   'by',
#   'being',
#   'greeted',
#   'with',
#   'shouts',
#   'laughter',
#   'by',
#   'false',
#   'friend',
#   'garnett',
#   'can',
#   'say',
#   'own',
#   'favour',
#   'was',
#   'boy',
#   'humane',
#   'but',
#   'owed',
#   'this',
#   'entirely',
#   'instruction',
#   'example',
#   'sisters',
#   'doubt',
#   'indeed',
#   'whether',
#   'humanity',
#   'natural',
#   'or',
#   'innate',
#   'quality',
#   'was',
#   'very',
#   'fond',
#   'collecting',
#   'eggs',
#   'but',
#   'never',
#   'took',
#   'more',
#   'than',
#   'single',
#   'egg',
#   'out',
#   'bird',
#   's',
#   'nest',
#   'except',
#   'on',
#   'one',
#   'single',
#   'occasion',
#   'when',
#   'took',
#   'all',
#   'not',
#   'their',
#   'value',
#   'but',
#   'from',
#   'sort',
#   'bravado',
#   'had',
#   'strong',
#   'taste',
#   'angling',
#   'would',
#   'sit',
#   'any',
#   'number',
#   'hours',
#   'on',
#   'bank',
#   'river',
#   'or',
#   'pond',
#   'watching',
#   'float',
#   'when',
#   'maer',
#   'house',
#   'his',
#   'uncle',
#   'josiah',
#   'wedgwood',
#   'was',
#   'told',
#   'could',
#   'kill',
#   'worms',
#   'with',
#   'salt',
#   'water',
#   'from',
#   'day',
#   'never',
#   'spitted',
#   'living',
#   'worm',
#   'though',
#   'expense',
#   'probably',
#   'loss',
#   'success',
#   'once',
#   'very',
#   'little',
#   'boy',
#   'whilst',
#   'day',
#   'school',
#   'or',
#   'before',
#   'time',
#   'acted',
#   'cruelly',
#   'beat',
#   'puppy',
#   'believe',
#   'simply',
#   'from',
#   'enjoying',
#   'sense',
#   'power',
#   'but',
#   'beating',
#   'could',
#   'not',
#   'have',
#   'been',
#   'severe',
#   'puppy',
#   'did',
#   'not',
#   'howl',
#   'feel',
#   'sure',
#   'spot',
#   'was',
#   'near',
#   'house',
#   'this',
#   'act',
#   'lay',
#   'heavily',
#   'on',
#   'conscience',
#   'shown',
#   'by',
#   'remembering',
#   'exact',
#   'spot',
#   'where',
#   'crime',
#   'was',
#   'committed',
#   'it',
#   'probably',
#   'lay',
#   'all',
#   'heavier',
#   'from',
#   'love',
#   'dogs',
#   'being',
#   'then',
#   'long',
#   'time',
#   'afterwards',
#   'passion',
#   'dogs',
#   'seemed',
#   'know',
#   'this',
#   'was',
#   'an',
#   'adept',
#   'robbing',
#   'their',
#   'love',
#   'from',
#   'their',
#   'masters',
#   'remember',
#   'clearly',
#   'only',
#   'one',
#   'other',
#   'incident',
#   'during',
#   'this',
#   'year',
#   'whilst',
#   'mr',
#   'case',
#   's',
#   'daily',
#   'school',
#   'namely',
#   'burial',
#   'dragoon',
#   'soldier',
#   'it',
#   'surprising',
#   'how',
#   'clearly',
#   'can',
#   ...],
#  ['coral',
#   'reefs',
#   'by',
#   'charles',
#   'darwin',
#   'editorial',
#   'note',
#   'although',
#   'respects',
#   'more',
#   'technical',
#   'their',
#   'subjects',
#   'style',
#   'than',
#   'darwin',
#   's',
#   'journal',
#   'books',
#   'here',
#   'reprinted',
#   'will',
#   'never',
#   'lose',
#   'their',
#   'value',
#   'interest',
#   'originality',
#   'observations',
#   'they',
#   'contain',
#   'many',
#   'parts',
#   'them',
#   'are',
#   'admirably',
#   'adapted',
#   'giving',
#   'an',
#   'insight',
#   'into',
#   'problems',
#   'regarding',
#   'structure',
#   'changes',
#   'earth',
#   's',
#   'surface',
#   'fact',
#   'they',
#   'form',
#   'charming',
#   'introduction',
#   'physical',
#   'geology',
#   'physiography',
#   'their',
#   'application',
#   'special',
#   'domains',
#   'books',
#   'themselves',
#   'cannot',
#   'obtained',
#   'many',
#   'times',
#   'price',
#   'present',
#   'volume',
#   'both',
#   'general',
#   'reader',
#   'desires',
#   'know',
#   'more',
#   'darwin',
#   's',
#   'work',
#   'student',
#   'geology',
#   'naturally',
#   'wishes',
#   'know',
#   'how',
#   'master',
#   'mind',
#   'reasoned',
#   'on',
#   'most',
#   'important',
#   'geological',
#   'subjects',
#   'will',
#   'glad',
#   'opportunity',
#   'possessing',
#   'them',
#   'convenient',
#   'cheap',
#   'form',
#   'three',
#   'introductions',
#   'friend',
#   'professor',
#   'judd',
#   'has',
#   'kindly',
#   'furnished',
#   'give',
#   'critical',
#   'historical',
#   'information',
#   'makes',
#   'this',
#   'edition',
#   'special',
#   'value',
#   'g',
#   't',
#   'b',
#   'coral',
#   'reefs',
#   'table',
#   'contents',
#   'critical',
#   'introduction',
#   'introduction',
#   'chapter',
#   'atolls',
#   'or',
#   'lagoon',
#   'islands',
#   'section',
#   '1',
#   'description',
#   'keeling',
#   'atoll',
#   'corals',
#   'on',
#   'outer',
#   'margin',
#   'zone',
#   'nulliporae',
#   'exterior',
#   'reef',
#   'islets',
#   'coral',
#   'conglomerate',
#   'lagoon',
#   'calcareous',
#   'sediment',
#   'scari',
#   'holuthuriae',
#   'subsisting',
#   'on',
#   'corals',
#   'changes',
#   'condition',
#   'reefs',
#   'islets',
#   'probable',
#   'subsidence',
#   'atoll',
#   'future',
#   'state',
#   'lagoon',
#   'section',
#   '1',
#   'ii',
#   'general',
#   'description',
#   'atolls',
#   'general',
#   'form',
#   'size',
#   'atolls',
#   'their',
#   'reefs',
#   'islets',
#   'external',
#   'slope',
#   'zone',
#   'nulliporae',
#   'conglomerate',
#   'depth',
#   'lagoons',
#   'sediment',
#   'reefs',
#   'submerged',
#   'wholly',
#   'or',
#   'part',
#   'breaches',
#   'reef',
#   'ledge',
#   'formed',
#   'shores',
#   'round',
#   'certain',
#   'lagoons',
#   'conversion',
#   'lagoons',
#   'into',
#   'land',
#   'section',
#   '1',
#   'iii',
#   'atolls',
#   'maldiva',
#   'archipelago',
#   'great',
#   'chagos',
#   'bank',
#   'maldiva',
#   'archipelago',
#   'ring',
#   'formed',
#   'reefs',
#   'marginal',
#   'central',
#   'great',
#   'depths',
#   'lagoons',
#   'southern',
#   'atolls',
#   'reefs',
#   'lagoons',
#   'all',
#   'rising',
#   'surface',
#   'position',
#   'islets',
#   'breaches',
#   'reefs',
#   'with',
#   'respect',
#   'prevalent',
#   'winds',
#   'action',
#   'waves',
#   'destruction',
#   'islets',
#   'connection',
#   'position',
#   'submarine',
#   'foundation',
#   'distinct',
#   'atolls',
#   'apparent',
#   'disseverment',
#   'large',
#   'atolls',
#   'great',
#   'chagos',
#   'bank',
#   'its',
#   'submerged',
#   'condition',
#   'extraordinary',
#   'structure',
#   'chapter',
#   'ii',
#   'barrier',
#   'reefs',
#   'closely',
#   'resemble',
#   'general',
#   'form',
#   'structure',
#   'atoll',
#   'reefs',
#   'width',
#   'depth',
#   'lagoon',
#   'channels',
#   'breaches',
#   'through',
#   'reef',
#   'front',
#   'valleys',
#   'generally',
#   'on',
#   'leeward',
#   'side',
#   'checks',
#   'filling',
#   'up',
#   'lagoon',
#   'channels',
#   'size',
#   'constitution',
#   'encircled',
#   'islands',
#   'number',
#   'islands',
#   'within',
#   'same',
#   'reef',
#   'barrier',
#   'reefs',
#   'new',
#   'caledonia',
#   'australia',
#   'position',
#   'reef',
#   'relative',
#   'slope',
#   'adjoining',
#   'land',
#   'probable',
#   'great',
#   'thickness',
#   'barrier',
#   'reefs',
#   'chapter',
#   'iii',
#   'fringing',
#   'or',
#   'shore',
#   'reefs',
#   'reefs',
#   'mauritius',
#   'shallow',
#   'channel',
#   'within',
#   'reef',
#   'its',
#   'slow',
#   'filling',
#   'up',
#   'currents',
#   'water',
#   'formed',
#   'within',
#   'it',
#   'upraised',
#   'reefs',
#   'narrow',
#   'fringing',
#   'reefs',
#   'deep',
#   'seas',
#   'reefs',
#   'on',
#   'coast',
#   'e',
#   'africa',
#   'brazil',
#   'fringing',
#   'reefs',
#   'very',
#   'shallow',
#   'seas',
#   'round',
#   'banks',
#   'sediment',
#   'on',
#   'worn',
#   'down',
#   'islands',
#   'fringing',
#   'reefs',
#   'affected',
#   'by',
#   'currents',
#   'sea',
#   'coral',
#   'coating',
#   'bottom',
#   'sea',
#   'but',
#   'not',
#   'forming',
#   'reefs',
#   'chapter',
#   'iv',
#   'on',
#   'distribution',
#   'growth',
#   'coral',
#   'reefs',
#   'section',
#   '4',
#   'on',
#   'distribution',
#   'coral',
#   'reefs',
#   'on',
#   'conditions',
#   'favourable',
#   'their',
#   'increase',
#   'section',
#   '4',
#   'ii',
#   'on',
#   'rate',
#   'growth',
#   'coral',
#   'reefs',
#   'section',
#   '4',
#   'iii',
#   'on',
#   'depths',
#   'reef',
#   'building',
#   'polypifers',
#   'can',
#   'live',
#   'chapter',
#   'v',
#   'theory',
#   'formation',
#   'different',
#   'classes',
#   'coral',
#   'reefs',
#   'atolls',
#   'larger',
#   'archipelagoes',
#   'are',
#   'not',
#   'formed',
#   'on',
#   'submerged',
#   'craters',
#   'or',
#   'on',
#   'banks',
#   'sediment',
#   'immense',
#   'areas',
#   'interspersed',
#   'with',
#   'atolls',
#   'recent',
#   'changes',
#   'their',
#   'state',
#   'origin',
#   'barrier',
#   'reefs',
#   'atolls',
#   'their',
#   'relative',
#   'forms',
#   'step',
#   'formed',
#   'ledges',
#   'walls',
#   'round',
#   'shores',
#   'lagoons',
#   'ring',
#   'formed',
#   'reefs',
#   'maldiva',
#   'atolls',
#   'submerged',
#   'condition',
#   'parts',
#   'or',
#   'whole',
#   'annular',
#   'reefs',
#   'disseverment',
#   'large',
#   'atolls',
#   'union',
#   'atolls',
#   'by',
#   'linear',
#   'reefs',
#   'great',
#   'chagos',
#   'bank',
#   'objections',
#   'from',
#   'area',
#   'amount',
#   'subsidence',
#   'required',
#   'by',
#   'theory',
#   'considered',
#   'probable',
#   'composition',
#   'lower',
#   'parts',
#   'atolls',
#   'chapter',
#   'vi',
#   'on',
#   'distribution',
#   'coral',
#   'reefs',
#   'with',
#   'reference',
#   'theory',
#   'their',
#   'formation',
#   'description',
#   'coloured',
#   'map',
#   'proximity',
#   'atolls',
#   'barrier',
#   'reefs',
#   'relation',
#   'form',
#   'position',
#   'atolls',
#   'with',
#   'ordinary',
#   'islands',
#   'direct',
#   'evidence',
#   'subsidence',
#   'difficult',
#   'detected',
#   'proofs',
#   'recent',
#   'elevation',
#   'where',
#   'fringing',
#   'reefs',
#   'occur',
#   'oscillations',
#   'level',
#   'absence',
#   'active',
#   'volcanoes',
#   'areas',
#   'subsidence',
#   'immensity',
#   'areas',
#   'have',
#   'been',
#   'elevated',
#   'have',
#   'subsided',
#   'their',
#   'relation',
#   'present',
#   'distribution',
#   'land',
#   'areas',
#   'subsidence',
#   'elongated',
#   'their',
#   'intersection',
#   'alternation',
#   'with',
#   'those',
#   'elevation',
#   'amount',
#   'slow',
#   'rate',
#   'subsidence',
#   'recapitulation',
#   'appendix',
#   'containing',
#   'detailed',
#   'description',
#   'reefs',
#   'islands',
#   'plate',
#   'iii',
#   'index',
#   'structure',
#   'distribution',
#   'coral',
#   'reefs',
#   'critical',
#   'introduction',
#   'scientific',
#   'discovery',
#   'outcome',
#   'an',
#   'interesting',
#   'process',
#   'evolution',
#   'mind',
#   'its',
#   'author',
#   'when',
#   'are',
#   'able',
#   'detect',
#   'germs',
#   'thought',
#   'such',
#   'discovery',
#   'has',
#   'originated',
#   'trace',
#   'successive',
#   'stages',
#   'reasoning',
#   'by',
#   'crude',
#   'idea',
#   'has',
#   'developed',
#   'into',
#   'an',
#   'epoch',
#   'making',
#   'book',
#   'have',
#   'materials',
#   'reconstructing',
#   'an',
#   'important',
#   'chapter',
#   'scientific',
#   'history',
#   'such',
#   'contribution',
#   'story',
#   'making',
#   'science',
#   'furnished',
#   'respect',
#   'darwin',
#   's',
#   'famous',
#   'theory',
#   'coral',
#   'reefs',
#   'clearly',
#   'reasoned',
#   'treatise',
#   'it',
#   'was',
#   'first',
#   'fully',
#   'set',
#   'forth',
#   'subject',
#   'corals',
#   'coral',
#   'reefs',
#   'one',
#   'concerning',
#   'much',
#   'popular',
#   'misconception',
#   'has',
#   'always',
#   'prevailed',
#   'misleading',
#   'comparison',
#   'coral',
#   'rock',
#   'with',
#   'combs',
#   'bees',
#   'nests',
#   'wasps',
#   'perhaps',
#   'responsible',
#   'much',
#   'this',
#   'misunderstanding',
#   'one',
#   'writer',
#   'has',
#   'indeed',
#   'described',
#   'coral',
#   'reef',
#   'being',
#   'built',
#   'by',
#   'fishes',
#   'by',
#   'means',
#   'their',
#   'teeth',
#   'scarcely',
#   'less',
#   'misleading',
#   'however',
#   'are',
#   'references',
#   'so',
#   'frequently',
#   'meet',
#   'with',
#   'both',
#   'prose',
#   'verse',
#   'skill',
#   'industry',
#   'perseverance',
#   'coral',
#   'insect',
#   'building',
#   'his',
#   'home',
#   'praise',
#   'men',
#   'their',
#   'cleverness',
#   'making',
#   'their',
#   'own',
#   'skeletons',
#   'laud',
#   'their',
#   'assiduity',
#   'filling',
#   'churchyards',
#   'with',
#   'same',
#   'polyps',
#   'other',
#   'organisms',
#   'whose',
#   'remains',
#   'accumulate',
#   'form',
#   'coral',
#   'reef',
#   'simply',
#   'live',
#   'perform',
#   'their',
#   'natural',
#   'functions',
#   'then',
#   'die',
#   'leaving',
#   'behind',
#   'them',
#   'natural',
#   'course',
#   'events',
#   'hard',
#   'calcareous',
#   'portions',
#   'their',
#   'structures',
#   'add',
#   'growing',
#   'reef',
#   'while',
#   'forms',
#   'coral',
#   'reefs',
#   'coral',
#   'islands',
#   'are',
#   'sometimes',
#   'very',
#   'remarkable',
#   'worthy',
#   'attentive',
#   'study',
#   'there',
#   'no',
#   'ground',
#   'it',
#   'need',
#   'scarcely',
#   'added',
#   'suggestion',
#   'they',
#   'afford',
#   'proofs',
#   'design',
#   'on',
#   'part',
#   'living',
#   'builders',
#   'or',
#   'words',
#   'flinders',
#   'they',
#   'constitute',
#   'breastworks',
#   'defending',
#   'workshops',
#   'from',
#   'whence',
#   'infant',
#   'colonies',
#   'safely',
#   'sent',
#   'forth',
#   'it',
#   'was',
#   'not',
#   'till',
#   'beginning',
#   'present',
#   'century',
#   'travellers',
#   'like',
#   'beechey',
#   'chamisso',
#   'quoy',
#   'gaimard',
#   'moresby',
#   'nelson',
#   'others',
#   'began',
#   'collect',
#   'accurate',
#   'details',
#   'concerning',
#   'forms',
#   'structure',
#   'coral',
#   'masses',
#   'make',
#   'such',
#   'observations',
#   'on',
#   'habits',
#   'reef',
#   'forming',
#   'polyps',
#   'serve',
#   'basis',
#   'safe',
#   'reasoning',
#   'concerning',
#   'origin',
#   'coral',
#   'reefs',
#   'islands',
#   'second',
#   'volume',
#   'lyell',
#   's',
#   'principles',
#   'geology',
#   'published',
#   '1832',
#   'final',
#   'chapter',
#   'gives',
#   'an',
#   'admirable',
#   'summary',
#   'all',
#   'was',
#   'then',
#   'known',
#   'on',
#   'subject',
#   'time',
#   'ring',
#   'form',
#   'atolls',
#   'was',
#   'almost',
#   'universally',
#   'regarded',
#   'proof',
#   'they',
#   'had',
#   'grown',
#   'up',
#   'on',
#   'submerged',
#   'volcanic',
#   'craters',
#   'lyell',
#   'gave',
#   'his',
#   'powerful',
#   'support',
#   'theory',
#   'charles',
#   'darwin',
#   'was',
#   'never',
#   'tired',
#   'acknowledging',
#   'his',
#   'indebtedness',
#   'lyell',
#   'dedicating',
#   'his',
#   'friend',
#   'second',
#   'edition',
#   'his',
#   'naturalist',
#   's',
#   'voyage',
#   'round',
#   'world',
#   'darwin',
#   'writes',
#   'he',
#   'does',
#   'so',
#   'with',
#   'grateful',
#   'pleasure',
#   'an',
#   'acknowledgment',
#   'chief',
#   'part',
#   'whatever',
#   'scientific',
#   'merit',
#   'this',
#   'journal',
#   'other',
#   'works',
#   'author',
#   'possess',
#   'has',
#   'been',
#   'derived',
#   'from',
#   'studying',
#   'known',
#   'admirable',
#   'principles',
#   'geology',
#   'second',
#   'volume',
#   'lyell',
#   's',
#   'principles',
#   'appeared',
#   'after',
#   'darwin',
#   'had',
#   'left',
#   'england',
#   'but',
#   'it',
#   'was',
#   'doubtless',
#   'sent',
#   'on',
#   'him',
#   'without',
#   'delay',
#   'by',
#   'his',
#   'faithful',
#   'friend',
#   'correspondent',
#   'professor',
#   'henslow',
#   'it',
#   'appears',
#   'have',
#   'reached',
#   'darwin',
#   'most',
#   'opportune',
#   'moment',
#   'while',
#   'fact',
#   'he',
#   'was',
#   'studying',
#   'striking',
#   'evidences',
#   'slow',
#   'long',
#   'continued',
#   'but',
#   'often',
#   'interrupted',
#   'movement',
#   'on',
#   'west',
#   'coast',
#   'south',
#   'america',
#   'darwin',
#   's',
#   'acute',
#   'mind',
#   'could',
#   'not',
#   'fail',
#   'detect',
#   'weakness',
#   'then',
#   'prevalent',
#   'theory',
#   'concerning',
#   'origin',
#   'ring',
#   'shaped',
#   'atolls',
#   'difficulty',
#   'he',
#   ...],
#  ['descent',
#   'man',
#   'selection',
#   'relation',
#   'sex',
#   'works',
#   'by',
#   'charles',
#   'darwin',
#   'f',
#   'r',
#   's',
#   'life',
#   'letters',
#   'charles',
#   'darwin',
#   'with',
#   'an',
#   'autobiographical',
#   'chapter',
#   'edited',
#   'by',
#   'francis',
#   'darwin',
#   'portraits',
#   '3',
#   'volumes',
#   '36s',
#   'popular',
#   'edition',
#   'condensed',
#   '1',
#   'volume',
#   '7s',
#   '6d',
#   'naturalist',
#   's',
#   'journal',
#   'researches',
#   'into',
#   'natural',
#   'history',
#   'geology',
#   'countries',
#   'visited',
#   'during',
#   'voyage',
#   'round',
#   'world',
#   'with',
#   '100',
#   'illustrations',
#   'by',
#   'pritchett',
#   '21s',
#   'popular',
#   'edition',
#   'woodcuts',
#   '3s',
#   '6d',
#   'cheaper',
#   'edition',
#   '2s',
#   '6d',
#   'net',
#   'origin',
#   'species',
#   'by',
#   'means',
#   'natural',
#   'selection',
#   'or',
#   'preservation',
#   'favoured',
#   'races',
#   'struggle',
#   'life',
#   'large',
#   'type',
#   'edition',
#   '2',
#   'volumes',
#   '12s',
#   'popular',
#   'edition',
#   '6s',
#   'cheaper',
#   'edition',
#   'with',
#   'portrait',
#   '2s',
#   '6d',
#   'various',
#   'contrivances',
#   'by',
#   'orchids',
#   'are',
#   'fertilized',
#   'by',
#   'insects',
#   'woodcuts',
#   '7s',
#   '6d',
#   'variation',
#   'animals',
#   'plants',
#   'under',
#   'domestication',
#   'illustrations',
#   '15s',
#   'descent',
#   'man',
#   'selection',
#   'relation',
#   'sex',
#   'illustrations',
#   'large',
#   'type',
#   'edition',
#   '2',
#   'volumes',
#   '15s',
#   'popular',
#   'edition',
#   '7s',
#   '6d',
#   'cheaper',
#   'edition',
#   '2s',
#   '6d',
#   'net',
#   'expression',
#   'emotions',
#   'man',
#   'animals',
#   'illustrations',
#   '12s',
#   'insectivorous',
#   'plants',
#   'illustrations',
#   '9s',
#   'movements',
#   'habits',
#   'climbing',
#   'plants',
#   'woodcuts',
#   '6s',
#   'cross',
#   'self',
#   'fertilization',
#   'vegetable',
#   'kingdom',
#   'illustrations',
#   '9s',
#   'different',
#   'forms',
#   'flowers',
#   'on',
#   'plants',
#   'same',
#   'species',
#   'illustrations',
#   '7s',
#   '6d',
#   'formation',
#   'vegetable',
#   'mould',
#   'through',
#   'action',
#   'worms',
#   'woodcuts',
#   '6s',
#   'above',
#   'works',
#   'are',
#   'published',
#   'by',
#   'john',
#   'murray',
#   'structure',
#   'distribution',
#   'coral',
#   'reefs',
#   'smith',
#   'elder',
#   'co',
#   'geological',
#   'observations',
#   'on',
#   'volcanic',
#   'islands',
#   'parts',
#   'south',
#   'america',
#   'smith',
#   'elder',
#   'co',
#   'monograph',
#   'cirripedia',
#   'illustrations',
#   '2',
#   'volumes',
#   '8vo',
#   'ray',
#   'society',
#   'monograph',
#   'fossil',
#   'lepadidae',
#   'or',
#   'pedunculated',
#   'cirripedes',
#   'great',
#   'britain',
#   'palaeontographical',
#   'society',
#   'monograph',
#   'fossil',
#   'balanidae',
#   'verrucidae',
#   'great',
#   'britain',
#   'palaeontographical',
#   'society',
#   'descent',
#   'man',
#   'selection',
#   'relation',
#   'sex',
#   'by',
#   'charles',
#   'darwin',
#   'm',
#   'f',
#   'r',
#   's',
#   'uniform',
#   'with',
#   'this',
#   'volume',
#   'origin',
#   'species',
#   'by',
#   'means',
#   'natural',
#   'selection',
#   'or',
#   'preservation',
#   'favoured',
#   'races',
#   'struggle',
#   'life',
#   'popular',
#   'edition',
#   'with',
#   'photogravure',
#   'portrait',
#   'large',
#   'crown',
#   '8vo',
#   '2s',
#   '6d',
#   'net',
#   'naturalist',
#   's',
#   'voyage',
#   'journal',
#   'researches',
#   'into',
#   'natural',
#   'history',
#   'geology',
#   'countries',
#   'visited',
#   'during',
#   'voyage',
#   'h',
#   'm',
#   's',
#   'beagle',
#   'round',
#   'world',
#   'under',
#   'command',
#   'capt',
#   'fitz',
#   'roy',
#   'r',
#   'n',
#   'popular',
#   'edition',
#   'with',
#   'many',
#   'illustrations',
#   'large',
#   'crown',
#   '8vo',
#   '2s',
#   '6d',
#   'net',
#   'preface',
#   'second',
#   'edition',
#   'during',
#   'successive',
#   'reprints',
#   'first',
#   'edition',
#   'this',
#   'work',
#   'published',
#   '1871',
#   'was',
#   'able',
#   'introduce',
#   'several',
#   'important',
#   'corrections',
#   'now',
#   'more',
#   'time',
#   'has',
#   'elapsed',
#   'have',
#   'endeavoured',
#   'profit',
#   'by',
#   'fiery',
#   'ordeal',
#   'through',
#   'book',
#   'has',
#   'passed',
#   'have',
#   'taken',
#   'advantage',
#   'all',
#   'criticisms',
#   'seem',
#   'me',
#   'sound',
#   'am',
#   'also',
#   'greatly',
#   'indebted',
#   'large',
#   'number',
#   'correspondents',
#   'communication',
#   'surprising',
#   'number',
#   'new',
#   'facts',
#   'remarks',
#   'these',
#   'have',
#   'been',
#   'so',
#   'numerous',
#   'have',
#   'been',
#   'able',
#   'use',
#   'only',
#   'more',
#   'important',
#   'ones',
#   'these',
#   'more',
#   'important',
#   'corrections',
#   'will',
#   'append',
#   'list',
#   'new',
#   'illustrations',
#   'have',
#   'been',
#   'introduced',
#   'four',
#   'old',
#   'drawings',
#   'have',
#   'been',
#   'replaced',
#   'by',
#   'better',
#   'ones',
#   'done',
#   'from',
#   'life',
#   'by',
#   'mr',
#   't',
#   'w',
#   'wood',
#   'must',
#   'especially',
#   'call',
#   'attention',
#   'observations',
#   'owe',
#   'kindness',
#   'prof',
#   'huxley',
#   'given',
#   'supplement',
#   'end',
#   'part',
#   'on',
#   'nature',
#   'differences',
#   'between',
#   'brains',
#   'man',
#   'higher',
#   'apes',
#   'have',
#   'been',
#   'particularly',
#   'glad',
#   'give',
#   'these',
#   'observations',
#   'because',
#   'during',
#   'last',
#   'few',
#   'years',
#   'several',
#   'memoirs',
#   'on',
#   'subject',
#   'have',
#   'appeared',
#   'on',
#   'continent',
#   'their',
#   'importance',
#   'has',
#   'been',
#   'cases',
#   'greatly',
#   'exaggerated',
#   'by',
#   'popular',
#   'writers',
#   'take',
#   'this',
#   'opportunity',
#   'remarking',
#   'critics',
#   'frequently',
#   'assume',
#   'attribute',
#   'all',
#   'changes',
#   'corporeal',
#   'structure',
#   'mental',
#   'power',
#   'exclusively',
#   'natural',
#   'selection',
#   'such',
#   'variations',
#   'are',
#   'often',
#   'called',
#   'spontaneous',
#   'whereas',
#   'even',
#   'first',
#   'edition',
#   'origin',
#   'species',
#   'distinctly',
#   'stated',
#   'great',
#   'weight',
#   'must',
#   'attributed',
#   'inherited',
#   'effects',
#   'use',
#   'disuse',
#   'with',
#   'respect',
#   'both',
#   'body',
#   'mind',
#   'also',
#   'attributed',
#   'amount',
#   'modification',
#   'direct',
#   'prolonged',
#   'action',
#   'changed',
#   'conditions',
#   'life',
#   'allowance',
#   'too',
#   'must',
#   'made',
#   'occasional',
#   'reversions',
#   'structure',
#   'nor',
#   'must',
#   'forget',
#   'what',
#   'have',
#   'called',
#   'correlated',
#   'growth',
#   'meaning',
#   'thereby',
#   'various',
#   'parts',
#   'organisation',
#   'are',
#   'unknown',
#   'manner',
#   'so',
#   'connected',
#   'when',
#   'one',
#   'part',
#   'varies',
#   'so',
#   'do',
#   'others',
#   'if',
#   'variations',
#   'one',
#   'are',
#   'accumulated',
#   'by',
#   'selection',
#   'other',
#   'parts',
#   'will',
#   'modified',
#   'again',
#   'it',
#   'has',
#   'been',
#   'said',
#   'by',
#   'several',
#   'critics',
#   'when',
#   'found',
#   'many',
#   'details',
#   'structure',
#   'man',
#   'could',
#   'not',
#   'explained',
#   'through',
#   'natural',
#   'selection',
#   'invented',
#   'sexual',
#   'selection',
#   'gave',
#   'however',
#   'tolerably',
#   'clear',
#   'sketch',
#   'this',
#   'principle',
#   'first',
#   'edition',
#   'origin',
#   'species',
#   'there',
#   'stated',
#   'it',
#   'was',
#   'applicable',
#   'man',
#   'this',
#   'subject',
#   'sexual',
#   'selection',
#   'has',
#   'been',
#   'treated',
#   'full',
#   'length',
#   'present',
#   'work',
#   'simply',
#   'because',
#   'an',
#   'opportunity',
#   'was',
#   'here',
#   'first',
#   'afforded',
#   'me',
#   'have',
#   'been',
#   'struck',
#   'with',
#   'likeness',
#   'many',
#   'half',
#   'favourable',
#   'criticisms',
#   'on',
#   'sexual',
#   'selection',
#   'with',
#   'those',
#   'appeared',
#   'first',
#   'on',
#   'natural',
#   'selection',
#   'such',
#   'it',
#   'would',
#   'explain',
#   'few',
#   'details',
#   'but',
#   'certainly',
#   'was',
#   'not',
#   'applicable',
#   'extent',
#   'have',
#   'employed',
#   'it',
#   'conviction',
#   'power',
#   'sexual',
#   'selection',
#   'remains',
#   'unshaken',
#   'but',
#   'it',
#   'probable',
#   'or',
#   'almost',
#   'certain',
#   'several',
#   'conclusions',
#   'will',
#   'hereafter',
#   'found',
#   'erroneous',
#   'this',
#   'can',
#   'hardly',
#   'fail',
#   'case',
#   'first',
#   'treatment',
#   'subject',
#   'when',
#   'naturalists',
#   'have',
#   'become',
#   'familiar',
#   'with',
#   'idea',
#   'sexual',
#   'selection',
#   'it',
#   'will',
#   'believe',
#   'much',
#   'more',
#   'largely',
#   'accepted',
#   'it',
#   'has',
#   'already',
#   'been',
#   'fully',
#   'favourably',
#   'received',
#   'by',
#   'several',
#   'capable',
#   'judges',
#   'down',
#   'beckenham',
#   'kent',
#   'september',
#   '1874',
#   'first',
#   'edition',
#   'february',
#   '24',
#   '1871',
#   'second',
#   'edition',
#   'september',
#   '1874',
#   'contents',
#   'introduction',
#   'part',
#   'descent',
#   'or',
#   'origin',
#   'man',
#   'chapter',
#   'evidence',
#   'descent',
#   'man',
#   'from',
#   'lower',
#   'form',
#   'nature',
#   'evidence',
#   'bearing',
#   'on',
#   'origin',
#   'man',
#   'homologous',
#   'structures',
#   'man',
#   'lower',
#   'animals',
#   'miscellaneous',
#   'points',
#   'correspondence',
#   'development',
#   'rudimentary',
#   'structures',
#   'muscles',
#   'sense',
#   'organs',
#   'hair',
#   'bones',
#   'reproductive',
#   'organs',
#   'etc',
#   'bearing',
#   'these',
#   'three',
#   'great',
#   'classes',
#   'facts',
#   'on',
#   'origin',
#   'man',
#   'chapter',
#   'ii',
#   'on',
#   'manner',
#   'development',
#   'man',
#   'from',
#   'lower',
#   'form',
#   'variability',
#   'body',
#   'mind',
#   'man',
#   'inheritance',
#   'causes',
#   'variability',
#   'laws',
#   'variation',
#   'same',
#   'man',
#   'lower',
#   'animals',
#   'direct',
#   'action',
#   'conditions',
#   'life',
#   'effects',
#   'increased',
#   'use',
#   'disuse',
#   'parts',
#   'arrested',
#   'development',
#   'reversion',
#   'correlated',
#   'variation',
#   'rate',
#   'increase',
#   'checks',
#   'increase',
#   'natural',
#   'selection',
#   'man',
#   'most',
#   'dominant',
#   'animal',
#   'world',
#   'importance',
#   'his',
#   'corporeal',
#   'structure',
#   'causes',
#   'have',
#   'led',
#   'his',
#   'becoming',
#   'erect',
#   'consequent',
#   'changes',
#   'structure',
#   'decrease',
#   'size',
#   'canine',
#   'teeth',
#   'increased',
#   'size',
#   'altered',
#   'shape',
#   'skull',
#   'nakedness',
#   'absence',
#   'tail',
#   'defenceless',
#   'condition',
#   'man',
#   'chapter',
#   'iii',
#   'comparison',
#   'mental',
#   'powers',
#   'man',
#   'lower',
#   'animals',
#   'difference',
#   'mental',
#   'power',
#   'between',
#   'highest',
#   'ape',
#   'lowest',
#   'savage',
#   'immense',
#   'certain',
#   'instincts',
#   'common',
#   'emotions',
#   'curiosity',
#   'imitation',
#   'attention',
#   'memory',
#   'imagination',
#   'reason',
#   'progressive',
#   'improvement',
#   'tools',
#   'weapons',
#   'used',
#   'by',
#   'animals',
#   'abstraction',
#   'self',
#   'consciousness',
#   'language',
#   'sense',
#   'beauty',
#   'belief',
#   'god',
#   'spiritual',
#   'agencies',
#   'superstitions',
#   'chapter',
#   'iv',
#   'comparison',
#   'mental',
#   'powers',
#   'man',
#   'lower',
#   'animals',
#   'continued',
#   'moral',
#   'sense',
#   'fundamental',
#   'proposition',
#   'qualities',
#   'social',
#   'animals',
#   'origin',
#   'sociability',
#   'struggle',
#   'between',
#   'opposed',
#   'instincts',
#   'man',
#   'social',
#   'animal',
#   'more',
#   'enduring',
#   'social',
#   'instincts',
#   'conquer',
#   'other',
#   'less',
#   'persistent',
#   'instincts',
#   'social',
#   'virtues',
#   'alone',
#   'regarded',
#   'by',
#   'savages',
#   'self',
#   'regarding',
#   'virtues',
#   'acquired',
#   'later',
#   'stage',
#   'development',
#   'importance',
#   'judgment',
#   'members',
#   'same',
#   'community',
#   'on',
#   'conduct',
#   'transmission',
#   'moral',
#   'tendencies',
#   'summary',
#   'chapter',
#   'v',
#   'on',
#   'development',
#   'intellectual',
#   'moral',
#   'faculties',
#   'during',
#   'primeval',
#   'civilised',
#   'times',
#   'advancement',
#   'intellectual',
#   'powers',
#   'through',
#   'natural',
#   'selection',
#   'importance',
#   'imitation',
#   'social',
#   'moral',
#   'faculties',
#   'their',
#   'development',
#   'within',
#   'limits',
#   'same',
#   'tribe',
#   'natural',
#   'selection',
#   'affecting',
#   'civilised',
#   'nations',
#   'evidence',
#   'civilised',
#   'nations',
#   'were',
#   'once',
#   'barbarous',
#   'chapter',
#   'vi',
#   'on',
#   'affinities',
#   'genealogy',
#   'man',
#   'position',
#   'man',
#   'animal',
#   'series',
#   'natural',
#   'system',
#   'genealogical',
#   'adaptive',
#   'characters',
#   'slight',
#   'value',
#   'various',
#   'small',
#   'points',
#   'resemblance',
#   'between',
#   'man',
#   'quadrumana',
#   'rank',
#   'man',
#   'natural',
#   'system',
#   'birthplace',
#   'antiquity',
#   'man',
#   ...],
#  ['different',
#   'forms',
#   'flowers',
#   'on',
#   'plants',
#   'same',
#   'species',
#   'by',
#   'charles',
#   'darwin',
#   'm',
#   'f',
#   'r',
#   's',
#   'professor',
#   'asa',
#   'gray',
#   'this',
#   'volume',
#   'dedicated',
#   'by',
#   'author',
#   'small',
#   'tribute',
#   'respect',
#   'affection',
#   'contents',
#   'introduction',
#   'chapter',
#   'heterostyled',
#   'dimorphic',
#   'plants',
#   'primulaceae',
#   'primula',
#   'veris',
#   'or',
#   'cowslip',
#   'differences',
#   'structure',
#   'between',
#   'two',
#   'forms',
#   'their',
#   'degrees',
#   'fertility',
#   'when',
#   'legitimately',
#   'illegitimately',
#   'united',
#   'p',
#   'elatior',
#   'vulgaris',
#   'sinensis',
#   'auricula',
#   'etc',
#   'summary',
#   'on',
#   'fertility',
#   'heterostyled',
#   'species',
#   'primula',
#   'homostyled',
#   'species',
#   'primula',
#   'hottonia',
#   'palustris',
#   'androsace',
#   'vitalliana',
#   'chapter',
#   'ii',
#   'hybrid',
#   'primulas',
#   'oxlip',
#   'hybrid',
#   'naturally',
#   'produced',
#   'between',
#   'primula',
#   'veris',
#   'vulgaris',
#   'differences',
#   'structure',
#   'function',
#   'between',
#   'two',
#   'parent',
#   'species',
#   'effects',
#   'crossing',
#   'long',
#   'styled',
#   'short',
#   'styled',
#   'oxlips',
#   'with',
#   'one',
#   'another',
#   'with',
#   'two',
#   'forms',
#   'both',
#   'parent',
#   'species',
#   'character',
#   'offspring',
#   'from',
#   'oxlips',
#   'artificially',
#   'self',
#   'fertilised',
#   'cross',
#   'fertilised',
#   'state',
#   'nature',
#   'primula',
#   'elatior',
#   'shown',
#   'distinct',
#   'species',
#   'hybrids',
#   'between',
#   'other',
#   'heterostyled',
#   'species',
#   'primula',
#   'supplementary',
#   'note',
#   'on',
#   'spontaneously',
#   'produced',
#   'hybrids',
#   'genus',
#   'verbascum',
#   'chapter',
#   'iii',
#   'heterostyled',
#   'dimorphic',
#   'plants',
#   'continued',
#   'linum',
#   'grandiflorum',
#   'long',
#   'styled',
#   'form',
#   'utterly',
#   'sterile',
#   'with',
#   'own',
#   'form',
#   'pollen',
#   'linum',
#   'perenne',
#   'torsion',
#   'pistils',
#   'long',
#   'styled',
#   'form',
#   'alone',
#   'homostyled',
#   'species',
#   'linum',
#   'pulmonaria',
#   'officinalis',
#   'singular',
#   'difference',
#   'self',
#   'fertility',
#   'between',
#   'english',
#   'german',
#   'long',
#   'styled',
#   'plants',
#   'pulmonaria',
#   'angustifolia',
#   'shown',
#   'distinct',
#   'species',
#   'long',
#   'styled',
#   'form',
#   'completely',
#   'self',
#   'sterile',
#   'polygonum',
#   'fagopyrum',
#   'various',
#   'other',
#   'heterostyled',
#   'genera',
#   'rubiaceae',
#   'mitchella',
#   'repens',
#   'fertility',
#   'flowers',
#   'pairs',
#   'houstonia',
#   'faramea',
#   'remarkable',
#   'difference',
#   'pollen',
#   'grains',
#   'two',
#   'forms',
#   'torsion',
#   'stamens',
#   'short',
#   'styled',
#   'form',
#   'alone',
#   'development',
#   'not',
#   'yet',
#   'perfect',
#   'heterostyled',
#   'structure',
#   'several',
#   'rubiaceous',
#   'genera',
#   'not',
#   'due',
#   'descent',
#   'common',
#   'chapter',
#   'iv',
#   'heterostyled',
#   'trimorphic',
#   'plants',
#   'lythrum',
#   'salicaria',
#   'description',
#   'three',
#   'forms',
#   'their',
#   'power',
#   'complex',
#   'manner',
#   'fertilising',
#   'one',
#   'another',
#   'eighteen',
#   'different',
#   'unions',
#   'possible',
#   'mid',
#   'styled',
#   'form',
#   'eminently',
#   'feminine',
#   'nature',
#   'lythrum',
#   'graefferi',
#   'likewise',
#   'trimorphic',
#   'l',
#   'hymifolia',
#   'dimorphic',
#   'l',
#   'hyssopifolia',
#   'homostyled',
#   'nesaea',
#   'verticillata',
#   'trimorphic',
#   'lagerstroemia',
#   'nature',
#   'doubtful',
#   'oxalis',
#   'trimorphic',
#   'species',
#   'o',
#   'valdiviana',
#   'o',
#   'regnelli',
#   'illegitimate',
#   'unions',
#   'quite',
#   'barren',
#   'o',
#   'speciosa',
#   'o',
#   'sensitiva',
#   'homostyled',
#   'species',
#   'oxalis',
#   'pontederia',
#   'one',
#   'monocotyledonous',
#   'genus',
#   'known',
#   'include',
#   'heterostyled',
#   'species',
#   'chapter',
#   'v',
#   'illegitimate',
#   'offspring',
#   'heterostyled',
#   'plants',
#   'illegitimate',
#   'offspring',
#   'from',
#   'all',
#   'three',
#   'forms',
#   'lythrum',
#   'salicaria',
#   'their',
#   'dwarfed',
#   'stature',
#   'sterility',
#   'utterly',
#   'barren',
#   'fertile',
#   'oxalis',
#   'transmission',
#   'form',
#   'legitimate',
#   'illegitimate',
#   'seedlings',
#   'primula',
#   'sinensis',
#   'illegitimate',
#   'offspring',
#   'degree',
#   'dwarfed',
#   'infertile',
#   'equal',
#   'styled',
#   'varieties',
#   'p',
#   'sinensis',
#   'auricula',
#   'farinosa',
#   'elatior',
#   'p',
#   'vulgaris',
#   'red',
#   'flowered',
#   'variety',
#   'illegitimate',
#   'seedlings',
#   'sterile',
#   'p',
#   'veris',
#   'illegitimate',
#   'plants',
#   'raised',
#   'during',
#   'several',
#   'successive',
#   'generations',
#   'their',
#   'dwarfed',
#   'stature',
#   'sterility',
#   'equal',
#   'styled',
#   'varieties',
#   'p',
#   'veris',
#   'transmission',
#   'form',
#   'by',
#   'pulmonaria',
#   'polygonum',
#   'concluding',
#   'remarks',
#   'close',
#   'parallelism',
#   'between',
#   'illegitimate',
#   'fertilisation',
#   'hybridism',
#   'chapter',
#   'vi',
#   'concluding',
#   'remarks',
#   'on',
#   'heterostyled',
#   'plants',
#   'essential',
#   'character',
#   'heterostyled',
#   'plants',
#   'summary',
#   'differences',
#   'fertility',
#   'between',
#   'legitimately',
#   'illegitimately',
#   'fertilised',
#   'plants',
#   'diameter',
#   'pollen',
#   'grains',
#   'size',
#   'anthers',
#   'structure',
#   'stigma',
#   'different',
#   'forms',
#   'affinities',
#   'genera',
#   'include',
#   'heterostyled',
#   'species',
#   'nature',
#   'advantages',
#   'derived',
#   'from',
#   'heterostylism',
#   'means',
#   'by',
#   'plants',
#   'became',
#   'heterostyled',
#   'transmission',
#   'form',
#   'equal',
#   'styled',
#   'varieties',
#   'heterostyled',
#   'plants',
#   'final',
#   'remarks',
#   'chapter',
#   'vii',
#   'polygamous',
#   'dioecious',
#   'gyno',
#   'dioecious',
#   'plants',
#   'conversion',
#   'various',
#   'ways',
#   'hermaphrodite',
#   'into',
#   'dioecious',
#   'plants',
#   'heterostyled',
#   'plants',
#   'rendered',
#   'dioecious',
#   'rubiaceae',
#   'verbenaceae',
#   'polygamous',
#   'sub',
#   'dioecious',
#   'plants',
#   'euonymus',
#   'fragaria',
#   'two',
#   'sub',
#   'forms',
#   'both',
#   'sexes',
#   'rhamnus',
#   'epigaea',
#   'ilex',
#   'gyno',
#   'dioecious',
#   'plants',
#   'thymus',
#   'difference',
#   'fertility',
#   'hermaphrodite',
#   'female',
#   'individuals',
#   'satureia',
#   'manner',
#   'two',
#   'forms',
#   'probably',
#   'originated',
#   'scabiosa',
#   'other',
#   'gyno',
#   'dioecious',
#   'plants',
#   'difference',
#   'size',
#   'corolla',
#   'forms',
#   'polygamous',
#   'dioecious',
#   'gyno',
#   'dioecious',
#   'plants',
#   'chapter',
#   'viii',
#   'cleistogamic',
#   'flowers',
#   'general',
#   'character',
#   'cleistogamic',
#   'flowers',
#   'list',
#   'genera',
#   'producing',
#   'such',
#   'flowers',
#   'their',
#   'distribution',
#   'vegetable',
#   'series',
#   'viola',
#   'description',
#   'cleistogamic',
#   'flowers',
#   'several',
#   'species',
#   'their',
#   'fertility',
#   'compared',
#   'with',
#   'perfect',
#   'flowers',
#   'oxalis',
#   'acetosella',
#   'o',
#   'sensitiva',
#   'three',
#   'forms',
#   'cleistogamic',
#   'flowers',
#   'vandellia',
#   'ononis',
#   'impatiens',
#   'drosera',
#   'miscellaneous',
#   'observations',
#   'on',
#   'various',
#   'other',
#   'cleistogamic',
#   'plants',
#   'anemophilous',
#   'species',
#   'producing',
#   'cleistogamic',
#   'flowers',
#   'leersia',
#   'perfect',
#   'flowers',
#   'rarely',
#   'developed',
#   'summary',
#   'concluding',
#   'remarks',
#   'on',
#   'origin',
#   'cleistogamic',
#   'flowers',
#   'chief',
#   'conclusions',
#   'drawn',
#   'from',
#   'observations',
#   'this',
#   'volume',
#   'index',
#   'different',
#   'forms',
#   'flowers',
#   'on',
#   'plants',
#   'same',
#   'species',
#   'introduction',
#   'subject',
#   'present',
#   'volume',
#   'namely',
#   'differently',
#   'formed',
#   'flowers',
#   'normally',
#   'produced',
#   'by',
#   'certain',
#   'kinds',
#   'plants',
#   'either',
#   'on',
#   'same',
#   'stock',
#   'or',
#   'on',
#   'distinct',
#   'stocks',
#   'ought',
#   'have',
#   'been',
#   'treated',
#   'by',
#   'professed',
#   'botanist',
#   'distinction',
#   'can',
#   'lay',
#   'no',
#   'claim',
#   'far',
#   'sexual',
#   'relations',
#   'flowers',
#   'are',
#   'concerned',
#   'linnaeus',
#   'long',
#   'ago',
#   'divided',
#   'them',
#   'into',
#   'hermaphrodite',
#   'monoecious',
#   'dioecious',
#   'polygamous',
#   'species',
#   'this',
#   'fundamental',
#   'distinction',
#   'with',
#   'aid',
#   'several',
#   'subdivisions',
#   'each',
#   'four',
#   'classes',
#   'will',
#   'serve',
#   'purpose',
#   'but',
#   'classification',
#   'artificial',
#   'groups',
#   'often',
#   'pass',
#   'into',
#   'one',
#   'another',
#   'hermaphrodite',
#   'class',
#   'contains',
#   'two',
#   'interesting',
#   'sub',
#   'groups',
#   'namely',
#   'heterostyled',
#   'cleistogamic',
#   'plants',
#   'but',
#   'there',
#   'are',
#   'several',
#   'other',
#   'less',
#   'important',
#   'subdivisions',
#   'presently',
#   'given',
#   'flowers',
#   'differing',
#   'various',
#   'ways',
#   'from',
#   'one',
#   'another',
#   'are',
#   'produced',
#   'by',
#   'same',
#   'species',
#   'plants',
#   'were',
#   'described',
#   'by',
#   'me',
#   'several',
#   'years',
#   'ago',
#   'series',
#   'papers',
#   'read',
#   'before',
#   'linnean',
#   'society',
#   'individuals',
#   'exist',
#   'under',
#   'two',
#   'or',
#   'three',
#   'forms',
#   'differing',
#   'length',
#   'their',
#   'pistils',
#   'stamens',
#   'other',
#   'respects',
#   'introduction',
#   '1',
#   'on',
#   'two',
#   'forms',
#   'or',
#   'dimorphic',
#   'condition',
#   'species',
#   'primula',
#   'on',
#   'their',
#   'remarkable',
#   'sexual',
#   'relations',
#   'journal',
#   'proceedings',
#   'linnean',
#   'society',
#   'volume',
#   '6',
#   '1862',
#   'page',
#   '77',
#   'on',
#   'existence',
#   'two',
#   'forms',
#   'on',
#   'their',
#   'reciprocal',
#   'sexual',
#   'relation',
#   'several',
#   'species',
#   'genus',
#   'linum',
#   'ibid',
#   'volume',
#   '7',
#   '1863',
#   'page',
#   '69',
#   'on',
#   'sexual',
#   'relations',
#   'three',
#   'forms',
#   'lythrum',
#   'salicaria',
#   'ibid',
#   'volume',
#   '8',
#   '1864',
#   'page',
#   '169',
#   'on',
#   'character',
#   'hybrid',
#   'like',
#   'nature',
#   'offspring',
#   'from',
#   'illegitimate',
#   'unions',
#   'dimorphic',
#   'trimorphic',
#   'plants',
#   'ibid',
#   'volume',
#   '10',
#   '1868',
#   'page',
#   '393',
#   'on',
#   'specific',
#   'differences',
#   'between',
#   'primula',
#   'veris',
#   'brit',
#   'fl',
#   'var',
#   'officinalis',
#   'linn',
#   'p',
#   'vulgaris',
#   'brit',
#   'fl',
#   'var',
#   'acaulis',
#   'linn',
#   'p',
#   'elatior',
#   'jacq',
#   'on',
#   'hybrid',
#   'nature',
#   'common',
#   'oxlip',
#   'with',
#   'supplementary',
#   'remarks',
#   'on',
#   'naturally',
#   'produced',
#   'hybrids',
#   'genus',
#   'verbascum',
#   'ibid',
#   'volume',
#   '10',
#   '1868',
#   'page',
#   '437',
#   'they',
#   'were',
#   'called',
#   'by',
#   'me',
#   'dimorphic',
#   'trimorphic',
#   'but',
#   'have',
#   'since',
#   'been',
#   'better',
#   'named',
#   'by',
#   'hildebrand',
#   'heterostyled',
#   'introduction',
#   '2',
#   'term',
#   'heterostyled',
#   'does',
#   'not',
#   'express',
#   'all',
#   'differences',
#   'between',
#   'forms',
#   'but',
#   'this',
#   'failure',
#   'common',
#   'many',
#   'cases',
#   'term',
#   'has',
#   'been',
#   'adopted',
#   'by',
#   'writers',
#   'various',
#   'countries',
#   'am',
#   'unwilling',
#   'change',
#   'it',
#   'heterogone',
#   'or',
#   'heterogonous',
#   'though',
#   'this',
#   'has',
#   'been',
#   'proposed',
#   'by',
#   'so',
#   'high',
#   'an',
#   'authority',
#   'professor',
#   'asa',
#   'gray',
#   'see',
#   'american',
#   'naturalist',
#   'january',
#   '1877',
#   'page',
#   '42',
#   'have',
#   'many',
#   'still',
#   'unpublished',
#   'observations',
#   'with',
#   'respect',
#   'these',
#   'plants',
#   'it',
#   'has',
#   'seemed',
#   'me',
#   'advisable',
#   'republish',
#   'former',
#   'papers',
#   'connected',
#   'corrected',
#   'form',
#   'together',
#   'with',
#   'new',
#   'matter',
#   'it',
#   'will',
#   'shown',
#   'these',
#   'heterostyled',
#   'plants',
#   'are',
#   'adapted',
#   'reciprocal',
#   'fertilisation',
#   'so',
#   'two',
#   'or',
#   'three',
#   'forms',
#   'though',
#   'all',
#   'are',
#   'hermaphrodites',
#   'are',
#   'related',
#   'one',
#   'another',
#   'almost',
#   'like',
#   'males',
#   'females',
#   'ordinary',
#   'unisexual',
#   'animals',
#   'will',
#   'also',
#   'give',
#   'full',
#   'abstract',
#   'such',
#   'observations',
#   'have',
#   'been',
#   'published',
#   'since',
#   'appearance',
#   'papers',
#   'but',
#   'only',
#   'those',
#   'cases',
#   'will',
#   'noticed',
#   'with',
#   'respect',
#   'evidence',
#   'seems',
#   'fairly',
#   'satisfactory',
#   'plants',
#   'have',
#   'been',
#   'supposed',
#   'heterostyled',
#   'merely',
#   'from',
#   'their',
#   'pistils',
#   'stamens',
#   'varying',
#   'greatly',
#   'length',
#   'have',
#   'been',
#   'myself',
#   'more',
#   'than',
#   'once',
#   'thus',
#   'deceived',
#   'with',
#   'species',
#   'pistil',
#   'continues',
#   'growing',
#   'long',
#   'time',
#   'so',
#   'if',
#   'old',
#   'young',
#   'flowers',
#   'are',
#   'compared',
#   'they',
#   ...],
#  ['effects',
#   'cross',
#   'self',
#   'fertilisation',
#   'vegetable',
#   'kingdom',
#   'by',
#   'charles',
#   'darwin',
#   'm',
#   'f',
#   'r',
#   's',
#   'etc',
#   'contents',
#   'chapter',
#   'introductory',
#   'remarks',
#   'various',
#   'means',
#   'favour',
#   'or',
#   'determine',
#   'cross',
#   'fertilisation',
#   'plants',
#   'benefits',
# ...
#   'were',
#   'collected',
#   'part',
#   'during',
#   'outward',
#   'voyage',
#   'when',
#   'beagle',
#   'called',
#   'st',
#   'jago',
#   'cape',
#   'de',
#   'verde',
#   'islands',
#   'st',
#   'paul',
#   's',
#   'rocks',
#   'fernando',
#   'noronha',
#   'but',
#   'mainly',
#   'during',
#   'homeward',
#   'cruise',
#   'then',
#   'it',
#   'was',
#   'galapagos',
#   'islands',
#   'were',
#   'surveyed',
#   'low',
#   'archipelago',
#   'passed',
#   'through',
#   'tahiti',
#   'visited',
#   'after',
#   'making',
#   'calls',
#   'bay',
#   'islands',
#   'new',
#   'zealand',
#   'also',
#   'sydney',
#   'hobart',
#   'town',
#   'king',
#   'george',
#   's',
#   'sound',
#   'australia',
#   'beagle',
#   'sailed',
#   'across',
#   'indian',
#   'ocean',
#   'little',
#   'group',
#   'keeling',
#   'or',
#   'cocos',
#   'islands',
#   'darwin',
#   'has',
#   'rendered',
#   'famous',
#   'by',
#   'his',
#   'observations',
#   'thence',
#   'mauritius',
#   'calling',
#   'cape',
#   'good',
#   'hope',
#   'on',
#   'her',
#   'way',
#   'ship',
#   'then',
#   'proceeded',
#   'successively',
#   'st',
#   'helena',
#   'ascension',
#   'revisited',
#   'cape',
#   'de',
#   'verde',
#   'islands',
#   'before',
#   'finally',
#   'reaching',
#   'england',
#   'although',
#   'darwin',
#   'was',
#   'thus',
#   'able',
#   'gratify',
#   'his',
#   'curiosity',
#   'by',
#   'visits',
#   'great',
#   'number',
#   'very',
#   'interesting',
#   'volcanic',
#   'districts',
#   'voyage',
#   'opened',
#   'him',
#   'with',
#   'bitter',
#   'disappointment',
#   'he',
#   'had',
#   'been',
#   'reading',
#   'humboldt',
#   's',
#   'personal',
#   'narrative',
#   'during',
#   'his',
#   'last',
#   'year',
#   's',
#   'residence',
#   'cambridge',
#   'had',
#   'copied',
#   'out',
#   'from',
#   'it',
#   'long',
#   'passages',
#   'about',
#   'teneriffe',
#   'he',
#   'was',
#   'actually',
#   'making',
#   'inquiries',
#   'best',
#   'means',
#   'visiting',
#   'island',
#   'when',
#   'offer',
#   'was',
#   'made',
#   'him',
#   'accompany',
#   'captain',
#   'fitzroy',
#   'beagle',
#   'his',
#   'friend',
#   'henslow',
#   'too',
#   'on',
#   'parting',
#   'with',
#   'him',
#   'had',
#   'given',
#   'him',
#   'advice',
#   'procure',
#   'read',
#   'recently',
#   'published',
#   'first',
#   'volume',
#   'principles',
#   'geology',
#   'though',
#   'he',
#   'warned',
#   'him',
#   'against',
#   'accepting',
#   'views',
#   'advocated',
#   'by',
#   'its',
#   'author',
#   'during',
#   'time',
#   'beagle',
#   'was',
#   'beating',
#   'backwards',
#   'forwards',
#   'when',
#   'voyage',
#   'commenced',
#   'darwin',
#   'although',
#   'hardly',
#   'ever',
#   'able',
#   'leave',
#   'his',
#   'berth',
#   'was',
#   'employing',
#   'all',
#   'opportunities',
#   'terrible',
#   'sea',
#   'sickness',
#   'left',
#   'him',
#   'studying',
#   'humboldt',
#   'lyell',
#   'therefore',
#   'form',
#   'an',
#   'idea',
#   'his',
#   'feelings',
#   'when',
#   'on',
#   'ship',
#   'reaching',
#   'santa',
#   'cruz',
#   'peak',
#   'teneriffe',
#   'making',
#   'its',
#   'appearance',
#   'among',
#   'clouds',
#   'they',
#   'were',
#   'suddenly',
#   'informed',
#   'an',
#   'outbreak',
#   'cholera',
#   'would',
#   'prevent',
#   'any',
#   'landing',
#   'ample',
#   'compensation',
#   'this',
#   'disappointment',
#   'was',
#   'found',
#   'however',
#   'when',
#   'ship',
#   'reached',
#   'porta',
#   'praya',
#   'st',
#   'jago',
#   'largest',
#   'cape',
#   'de',
#   'verde',
#   'islands',
#   'here',
#   'he',
#   'spent',
#   'three',
#   'most',
#   'delightful',
#   'weeks',
#   'really',
#   'commenced',
#   'his',
#   'work',
#   'geologist',
#   'naturalist',
#   'writing',
#   'his',
#   'father',
#   'he',
#   'says',
#   'geologising',
#   'volcanic',
#   'country',
#   'most',
#   'delightful',
#   'besides',
#   'interest',
#   'attached',
#   'itself',
#   'it',
#   'leads',
#   'you',
#   'into',
#   'most',
#   'beautiful',
#   'retired',
#   'spots',
#   'nobody',
#   'but',
#   'person',
#   'fond',
#   'natural',
#   'history',
#   'can',
#   'imagine',
#   'pleasure',
#   'strolling',
#   'under',
#   'cocoa',
#   'nuts',
#   'thicket',
#   'bananas',
#   'coffee',
#   'plants',
#   'an',
#   'endless',
#   'number',
#   'wild',
#   'flowers',
#   'this',
#   'island',
#   'has',
#   'given',
#   'me',
#   'so',
#   'much',
#   'instruction',
#   'delight',
#   'reckoned',
#   'most',
#   'uninteresting',
#   'place',
#   'perhaps',
#   'shall',
#   'touch',
#   'during',
#   'voyage',
#   'it',
#   'certainly',
#   'generally',
#   'very',
#   'barren',
#   'but',
#   'valleys',
#   'are',
#   'more',
#   'exquisitely',
#   'beautiful',
#   'from',
#   'very',
#   'contrast',
#   ...],
#  ['voyage',
#   'beagle',
#   'preface',
#   'have',
#   'stated',
#   'preface',
#   'first',
#   'edition',
#   'this',
#   'work',
#   'zoology',
#   'voyage',
#   'beagle',
#   'it',
#   'was',
#   'consequence',
#   'wish',
#   'expressed',
#   'by',
#   'captain',
#   'fitz',
#   'roy',
#   'having',
#   'scientific',
#   'person',
#   'on',
#   'board',
#   'accompanied',
#   'by',
#   'an',
#   'offer',
#   'from',
#   'him',
#   'giving',
#   'up',
#   'part',
#   'his',
#   'own',
#   'accommodations',
#   'volunteered',
#   'services',
#   'received',
#   'through',
#   'kindness',
#   'hydrographer',
#   'captain',
#   'beaufort',
#   'sanction',
#   'lords',
#   'admiralty',
#   'feel',
#   'opportunities',
#   'enjoyed',
#   'studying',
#   'natural',
#   'history',
#   'different',
#   'countries',
#   'visited',
#   'have',
#   'been',
#   'wholly',
#   'due',
#   'captain',
#   'fitz',
#   'roy',
#   'hope',
#   'here',
#   'permitted',
#   'repeat',
#   'expression',
#   'gratitude',
#   'him',
#   'add',
#   'during',
#   'five',
#   'years',
#   'were',
#   'together',
#   'received',
#   'from',
#   'him',
#   'most',
#   'cordial',
#   'friendship',
#   'steady',
#   'assistance',
#   'both',
#   'captain',
#   'fitz',
#   'roy',
#   'all',
#   'officers',
#   'beagle',
#   '1',
#   'shall',
#   'ever',
#   'feel',
#   'most',
#   'thankful',
#   'undeviating',
#   'kindness',
#   'with',
#   'was',
#   'treated',
#   'during',
#   'long',
#   'voyage',
#   'this',
#   'volume',
#   'contains',
#   'form',
#   'journal',
#   'history',
#   'voyage',
#   'sketch',
#   'those',
#   'observations',
#   'natural',
#   'history',
#   'geology',
#   'think',
#   'will',
#   'possess',
#   'interest',
#   'general',
#   'reader',
#   'have',
#   'this',
#   'edition',
#   'largely',
#   'condensed',
#   'corrected',
#   'parts',
#   'have',
#   'added',
#   'little',
#   'others',
#   'order',
#   'render',
#   'volume',
#   'more',
#   'fitted',
#   'popular',
#   'reading',
#   'but',
#   'trust',
#   'naturalists',
#   'will',
#   'remember',
#   'they',
#   'must',
#   'refer',
#   'details',
#   'larger',
#   'publications',
#   'comprise',
#   'scientific',
#   'results',
#   'expedition',
#   'zoology',
#   'voyage',
#   'beagle',
#   'includes',
#   'an',
#   'account',
#   'fossil',
#   'mammalia',
#   'by',
#   'professor',
#   'owen',
#   'living',
#   'mammalia',
#   'by',
#   'mr',
#   'waterhouse',
#   'birds',
#   'by',
#   'mr',
#   'gould',
#   'fish',
#   'by',
#   'rev',
#   'l',
#   'jenyns',
#   'reptiles',
#   'by',
#   'mr',
#   'bell',
#   'have',
#   'appended',
#   'descriptions',
#   'each',
#   'species',
#   'an',
#   'account',
#   'its',
#   'habits',
#   'range',
#   'these',
#   'works',
#   'owe',
#   'high',
#   'talents',
#   'disinterested',
#   'zeal',
#   'above',
#   'distinguished',
#   'authors',
#   'could',
#   'not',
#   'have',
#   'been',
#   'undertaken',
#   'had',
#   'it',
#   'not',
#   'been',
#   'liberality',
#   'lords',
#   'commissioners',
#   'her',
#   'majesty',
#   's',
#   'treasury',
#   'through',
#   'representation',
#   'right',
#   'honourable',
#   'chancellor',
#   'exchequer',
#   'have',
#   'been',
#   'pleased',
#   'grant',
#   'sum',
#   'one',
#   'thousand',
#   'pounds',
#   'towards',
#   'defraying',
#   'part',
#   'expenses',
#   'publication',
#   'have',
#   'myself',
#   'published',
#   'separate',
#   'volumes',
#   'on',
#   'structure',
#   'distribution',
#   'coral',
#   'reefs',
#   'on',
#   'volcanic',
#   'islands',
#   'visited',
#   'during',
#   'voyage',
#   'beagle',
#   'on',
#   'geology',
#   'south',
#   'america',
#   'sixth',
#   'volume',
#   'geological',
#   'transactions',
#   'contains',
#   'two',
#   'papers',
#   'mine',
#   'on',
#   'erratic',
#   'boulders',
#   'volcanic',
#   'phenomena',
#   'south',
#   'america',
#   'messrs',
#   'waterhouse',
#   'walker',
#   'newman',
#   'white',
#   'have',
#   'published',
#   'several',
#   'able',
#   'papers',
#   'on',
#   'insects',
#   'were',
#   'collected',
#   'trust',
#   'many',
#   'others',
#   'will',
#   'hereafter',
#   'follow',
#   'plants',
#   'from',
#   'southern',
#   'parts',
#   'america',
#   'will',
#   'given',
#   'by',
#   'dr',
#   'j',
#   'hooker',
#   'his',
#   'great',
#   'work',
#   'on',
#   'botany',
#   'southern',
#   'hemisphere',
#   'flora',
#   'galapagos',
#   'archipelago',
#   'subject',
#   'separate',
#   'memoir',
#   'by',
#   'him',
#   'linnean',
#   'transactions',
#   'reverend',
#   'professor',
#   'henslow',
#   'has',
#   'published',
#   'list',
#   'plants',
#   'collected',
#   'by',
#   'me',
#   'keeling',
#   'islands',
#   'reverend',
#   'j',
#   'm',
#   'berkeley',
#   'has',
#   'described',
#   'cryptogamic',
#   'plants',
#   'shall',
#   'have',
#   'pleasure',
#   'acknowledging',
#   'great',
#   'assistance',
#   'have',
#   'received',
#   'from',
#   'several',
#   'other',
#   'naturalists',
#   'course',
#   'this',
#   'other',
#   'works',
#   'but',
#   'must',
#   'here',
#   'allowed',
#   'return',
#   'most',
#   'sincere',
#   'thanks',
#   'reverend',
#   'professor',
#   'henslow',
#   'when',
#   'was',
#   'an',
#   'undergraduate',
#   'cambridge',
#   'was',
#   'one',
#   'chief',
#   'means',
#   'giving',
#   'me',
#   'taste',
#   'natural',
#   'history',
#   'during',
#   'absence',
#   'took',
#   'charge',
#   'collections',
#   'sent',
#   'home',
#   'by',
#   'his',
#   'correspondence',
#   'directed',
#   'endeavours',
#   'since',
#   'return',
#   'has',
#   'constantly',
#   'rendered',
#   'me',
#   'every',
#   'assistance',
#   'kindest',
#   'friend',
#   'could',
#   'offer',
#   'down',
#   'bromley',
#   'kent',
#   'june',
#   '9',
#   '1845',
#   '1',
#   'must',
#   'take',
#   'this',
#   'opportunity',
#   'returning',
#   'sincere',
#   'thanks',
#   'mr',
#   'bynoe',
#   'surgeon',
#   'beagle',
#   'his',
#   'very',
#   'kind',
#   'attention',
#   'me',
#   'when',
#   'was',
#   'ill',
#   'valparaiso',
#   'voyage',
#   'beagle',
#   'chapter',
#   'st',
#   'jago',
#   'cape',
#   'de',
#   'verd',
#   'islands',
#   'porto',
#   'praya',
#   'ribeira',
#   'grande',
#   'atmospheric',
#   'dust',
#   'with',
#   'infusoria',
#   'habits',
#   'sea',
#   'slug',
#   'cuttle',
#   'fish',
#   'st',
#   'paul',
#   's',
#   'rocks',
#   'non',
#   'volcanic',
#   'singular',
#   'incrustations',
#   'insects',
#   'first',
#   'colonists',
#   'islands',
#   'fernando',
#   'noronha',
#   'bahia',
#   'burnished',
#   'rocks',
#   'habits',
#   'diodon',
#   'pelagic',
#   'confervae',
#   'infusoria',
#   'causes',
#   'discoloured',
#   'sea',
#   'after',
#   'having',
#   'been',
#   'twice',
#   'driven',
#   'back',
#   'by',
#   'heavy',
#   'southwestern',
#   'gales',
#   'her',
#   'majesty',
#   's',
#   'ship',
#   'beagle',
#   'ten',
#   'gun',
#   'brig',
#   'under',
#   'command',
#   'captain',
#   'fitz',
#   'roy',
#   'r',
#   'n',
#   'sailed',
#   'from',
#   'devonport',
#   'on',
#   '27th',
#   'december',
#   '1831',
#   'object',
#   'expedition',
#   'was',
#   'complete',
#   'survey',
#   'patagonia',
#   'tierra',
#   'del',
#   'fuego',
#   'commenced',
#   'under',
#   'captain',
#   'king',
#   '1826',
#   '1830',
#   'survey',
#   'shores',
#   'chile',
#   'peru',
#   'islands',
#   'pacific',
#   'carry',
#   'chain',
#   'chronometrical',
#   'measurements',
#   'round',
#   'world',
#   'on',
#   '6th',
#   'january',
#   'reached',
#   'teneriffe',
#   'but',
#   'were',
#   'prevented',
#   'landing',
#   'by',
#   'fears',
#   'bringing',
#   'cholera',
#   'next',
#   'morning',
#   'saw',
#   'sun',
#   'rise',
#   'behind',
#   'rugged',
#   'outline',
#   'grand',
#   'canary',
#   'island',
#   'suddenly',
#   'illuminate',
#   'peak',
#   'teneriffe',
#   'whilst',
#   'lower',
#   'parts',
#   'were',
#   'veiled',
#   'fleecy',
#   'clouds',
#   'this',
#   'was',
#   'first',
#   'many',
#   'delightful',
#   'days',
#   'never',
#   'forgotten',
#   'on',
#   '16th',
#   'january',
#   '1832',
#   'anchored',
#   'porto',
#   'praya',
#   'st',
#   'jago',
#   'chief',
#   'island',
#   'cape',
#   'de',
#   'verd',
#   'archipelago',
#   'neighbourhood',
#   'porto',
#   'praya',
#   'viewed',
#   'from',
#   'sea',
#   'wears',
#   'desolate',
#   'aspect',
#   'volcanic',
#   'fires',
#   'past',
#   'age',
#   'scorching',
#   'heat',
#   'tropical',
#   'sun',
#   'have',
#   'most',
#   'places',
#   'rendered',
#   'soil',
#   'unfit',
#   'vegetation',
#   'country',
#   'rises',
#   'successive',
#   'steps',
#   'table',
#   'land',
#   'interspersed',
#   'with',
#   'truncate',
#   'conical',
#   'hills',
#   'horizon',
#   'bounded',
#   'by',
#   'an',
#   'irregular',
#   'chain',
#   'more',
#   'lofty',
#   'mountains',
#   'scene',
#   'beheld',
#   'through',
#   'hazy',
#   'atmosphere',
#   'this',
#   'climate',
#   'one',
#   'great',
#   'interest',
#   'if',
#   'indeed',
#   'person',
#   'fresh',
#   'from',
#   'sea',
#   'has',
#   'just',
#   'walked',
#   'first',
#   'time',
#   'grove',
#   'cocoa',
#   'nut',
#   'trees',
#   'can',
#   'judge',
#   'anything',
#   'but',
#   'his',
#   'own',
#   'happiness',
#   'island',
#   'would',
#   'generally',
#   'considered',
#   'very',
#   'uninteresting',
#   'but',
#   'anyone',
#   'accustomed',
#   'only',
#   'an',
#   'english',
#   'landscape',
#   'novel',
#   'aspect',
#   'an',
#   'utterly',
#   'sterile',
#   'land',
#   'possesses',
#   'grandeur',
#   'more',
#   'vegetation',
#   'spoil',
#   'single',
#   'green',
#   'leaf',
#   'can',
#   'scarcely',
#   'discovered',
#   'over',
#   'wide',
#   'tracts',
#   'lava',
#   'plains',
#   'yet',
#   'flocks',
#   'goats',
#   'together',
#   'with',
#   'few',
#   'cows',
#   'contrive',
#   'exist',
#   'it',
#   'rains',
#   'very',
#   'seldom',
#   'but',
#   'during',
#   'short',
#   'portion',
#   'year',
#   'heavy',
#   'torrents',
#   'fall',
#   'immediately',
#   'afterwards',
#   'light',
#   'vegetation',
#   'springs',
#   'out',
#   'every',
#   'crevice',
#   'this',
#   'soon',
#   'withers',
#   'upon',
#   'such',
#   'naturally',
#   'formed',
#   'hay',
#   'animals',
#   'live',
#   'it',
#   'had',
#   'not',
#   'now',
#   'rained',
#   'an',
#   'entire',
#   'year',
#   'when',
#   'island',
#   'was',
#   'discovered',
#   'immediate',
#   'neighbourhood',
#   'porto',
#   'praya',
#   'was',
#   'clothed',
#   'with',
#   'trees',
#   '1',
#   'reckless',
#   'destruction',
#   'has',
#   'caused',
#   'here',
#   'st',
#   'helena',
#   'canary',
#   'islands',
#   'almost',
#   'entire',
#   'sterility',
#   'broad',
#   'flat',
#   'bottomed',
#   'valleys',
#   'many',
#   'serve',
#   'during',
#   'few',
#   'days',
#   'only',
#   'season',
#   'water',
#   'courses',
#   'are',
#   'clothed',
#   'with',
#   'thickets',
#   'leafless',
#   'bushes',
#   'few',
#   'living',
#   'creatures',
#   'inhabit',
#   'these',
#   'valleys',
#   'commonest',
#   'bird',
#   'kingfisher',
#   'dacelo',
#   'iagoensis',
#   'tamely',
#   'sits',
#   'on',
#   'branches',
#   'castor',
#   'oil',
#   'plant',
#   'thence',
#   'darts',
#   'on',
#   'grasshoppers',
#   'lizards',
#   'it',
#   'brightly',
#   'coloured',
#   'but',
#   'not',
#   'so',
#   'beautiful',
#   'european',
#   'species',
#   'its',
#   'flight',
#   'manners',
#   'place',
#   'habitation',
#   'generally',
#   'driest',
#   'valley',
#   'there',
#   'also',
#   'wide',
#   'difference',
#   'one',
#   'day',
#   'two',
#   'officers',
#   'myself',
#   'rode',
#   'ribeira',
#   'grande',
#   'village',
#   'few',
#   'miles',
#   'eastward',
#   'porto',
#   'praya',
#   'until',
#   'reached',
#   'valley',
#   'st',
#   'martin',
#   'country',
#   'presented',
#   'its',
#   'usual',
#   'dull',
#   'brown',
#   'appearance',
#   'but',
#   'here',
#   'very',
#   'small',
#   'rill',
#   'water',
#   'produces',
#   'most',
#   'refreshing',
#   'margin',
#   'luxuriant',
#   'vegetation',
#   'course',
#   'an',
#   'hour',
#   'arrived',
#   'ribeira',
#   'grande',
#   'were',
#   'surprised',
#   'sight',
#   'large',
#   'ruined',
#   'fort',
#   'cathedral',
#   'this',
#   'little',
#   'town',
#   'before',
#   'its',
#   'harbour',
#   'was',
#   'filled',
#   'up',
#   'was',
#   'principal',
#   'place',
#   'island',
#   'it',
#   'now',
#   'presents',
#   'melancholy',
#   'but',
#   'very',
#   'picturesque',
#   'appearance',
#   'having',
#   'procured',
#   'black',
#   'padre',
#   'guide',
#   'spaniard',
#   'had',
#   'served',
#   'peninsular',
#   'war',
#   'an',
#   'interpreter',
#   'visited',
#   'collection',
#   'buildings',
#   'an',
#   'ancient',
#   'church',
#   'formed',
#   'principal',
#   'part',
#   'it',
#   'here',
#   'governors',
#   'captain',
#   'generals',
#   'islands',
#   'have',
#   'been',
#   'buried',
#   'tombstones',
#   'recorded',
#   'dates',
#   'sixteenth',
#   'century',
#   '2',
#   'heraldic',
#   'ornaments',
#   'were',
#   'only',
#   'things',
#   'this',
#   'retired',
#   'place',
#   'reminded',
#   'us',
#   'europe',
#   'church',
#   'or',
#   'chapel',
#   'formed',
#   'one',
#   'side',
#   'quadrangle',
#   'middle',
#   'large',
#   'clump',
#   'bananas',
#   'were',
#   'growing',
#   'on',
#   'another',
#   'side',
#   'was',
#   'hospital',
#   'containing',
#   'about',
#   'dozen',
#   'miserable',
#   'looking',
#   'inmates',
#   'returned',
#   'venda',
#   'eat',
#   'dinners',
#   'considerable',
#   'number',
#   'men',
#   ...]]

# %% [markdown]
# ## 5. Stemming of the tokenized corpus
# <p>If you have read <em>On the Origin of Species</em>, you will have noticed that Charles Darwin can use different words to refer to a similar concept. For example, the concept of selection can be described by words such as <em>selection</em>, <em>selective</em>, <em>select</em> or <em>selects</em>. This will dilute the weight given to this concept in the book and potentially bias the results of the analysis.</p>
# <p>To solve this issue, it is a common practice to use a <strong>stemming process</strong>, which will group together the inflected forms of a word so they can be analysed as a single item: <strong>the stem</strong>. In our <em>On the Origin of Species</em> example, the words related to the concept of selection would be gathered under the <em>select</em> stem.</p>
# <p>As we are analysing 20 full books, the stemming algorithm can take several minutes to run and, in order to make the process faster, we will directly load the final results from a pickle file and review the method used to generate it.</p>

# %%
#!pip3 install nltk

# %%
import pickle
import nltk

# Load the Porter stemming function from the nltk package
from nltk.stem import PorterStemmer

# Create an instance of a PorterStemmer object
porter = PorterStemmer()

# For each token of each text, we generated its stem 
texts_stem = [[porter.stem(token) for token in text] for text in texts]

# Save to pickle file
pickle.dump( texts_stem, open( "datasets/texts_stem.p", "wb" ) )

# Load the stemmed tokens list from the pregenerated pickle file
texts_stem = pickle.load( open( "datasets/texts_stem.p", "rb" ) )

# Print the 20 first stemmed tokens from the "On the Origin of Species" book
texts_stem[ori][0:20]
# Out:
# ['on',
#  'origin',
#  'speci',
#  'but',
#  'with',
#  'regard',
#  'materi',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'thi',
#  'can',
#  'perceiv',
#  'event',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 6. Building a bag-of-words model
# <p>Now that we have transformed the texts into stemmed tokens, we need to build models that will be useable by downstream algorithms.</p>
# <p>First, we need to will create a universe of all words contained in our corpus of Charles Darwin's books, which we call <em>a dictionary</em>. Then, using the stemmed tokens and the dictionary, we will create <strong>bag-of-words models</strong> (BoW) of each of our texts. The BoW models will represent our books as a list of all uniques tokens they contain associated with their respective number of occurrences. </p>
# <p>To better understand the structure of such a model, we will print the five first elements of one of the "<em>On the Origin of Species</em>" BoW model.</p>

# %%
#!pip3 install gensim

# %%
# Load the functions allowing to create and use dictionaries
from gensim import corpora

# Create a dictionary from the stemmed tokens
dictionary = corpora.Dictionary(texts_stem)

# Create a bag-of-words model for each book, using the previously generated dictionary
bows = [dictionary.doc2bow(text) for text in texts_stem]

# Print the first five elements of the On the Origin of species' BoW model
# ... YOUR CODE FOR TASK 6 ...
bows[ori][0:5]
# Out:
# [(0, 11), (5, 51), (6, 1), (8, 2), (21, 1)]

# %% [markdown]
# ## 7. The most common words of a given book
# <p>The results returned by the bag-of-words model is certainly easy to use for a computer but hard to interpret for a human. It is not straightforward to understand which stemmed tokens are present in a given book from Charles Darwin, and how many occurrences we can find.</p>
# <p>In order to better understand how the model has been generated and visualize its content, we will transform it into a DataFrame and display the 10 most common stems for the book "<em>On the Origin of Species</em>".</p>

# %%
# Import pandas to create and manipulate DataFrames
import pandas as pd

# Convert the BoW model for "On the Origin of Species" into a DataFrame
df_bow_origin = pd.DataFrame(bows[ori])

# Add the column names to the DataFrame
# ... YOUR CODE FOR TASK 7 ...
df_bow_origin.columns = ["index", "occurrences"]

# Add a column containing the token corresponding to the dictionary index
# ... YOUR CODE FOR TASK 7 ...
df_bow_origin["token"] = [dictionary[index] for index in df_bow_origin["index"]]

# Sort the DataFrame by descending number of occurrences and print the first 10 values
# ... YOUR CODE FOR TASK 7 ...
df_bow_origin.head(10).sort_values(by="occurrences", ascending = False).head(10)
# Out:
#    index  occurrences token
# 1      5           51    14
# 0      0           11     1
# 7     28            3  1845
# 3      8            2    16
# 5     23            2  1839
# 6     27            2  1844
# 2      6            1    15
# 4     21            1  1837
# 8     31            1  1854
# 9     35            1  1859

# %% [markdown]
# ## 8. Build a tf-idf model
# <p>If it wasn't for the presence of the stem "<em>speci</em>", we would have a hard time to guess this BoW model comes from the <em>On the Origin of Species</em> book. The most recurring words are, apart from few exceptions, very common and unlikely to carry any information peculiar to the given book. We need to use an additional step in order to determine which tokens are the most specific to a book.</p>
# <p>To do so, we will use a <strong>tf-idf model</strong> (term frequency–inverse document frequency). This model defines the importance of each word depending on how frequent it is in this text and how infrequent it is in all the other documents. As a result, a high tf-idf score for a word will indicate that this word is specific to this text.</p>
# <p>After computing those scores, we will print the 10 words most specific to the "<em>On the Origin of Species</em>" book (i.e., the 10 words with the highest tf-idf score).</p>

# %%
# Load the gensim functions that will allow us to generate tf-idf models
from gensim.models import TfidfModel

# Generate the tf-idf model
model = TfidfModel(bows)

# Print the model for "On the Origin of Species"
# ... YOUR CODE FOR TASK 8 ...
model[bows[ori]]
# Out:
# [(8, 0.00020408683039616044),
#  (21, 0.0005723177174474166),
#  (23, 0.001714008058633542),
#  (27, 0.0006466337090765656),
#  (28, 0.0025710120879503125),
#  (31, 0.000857004029316771),
#  (35, 0.001016241827361025),
#  (36, 0.001016241827361025),
#  (51, 0.0008878482198272165),
#  (54, 0.00203248365472205),
#  (56, 0.0023786863377481767),
#  (57, 0.00010204341519808022),
#  (63, 0.0027579084706411254),
#  (64, 0.000510217075990401),
#  (66, 0.00020408683039616044),
#  (67, 0.0023786863377481767),
#  (68, 0.00203248365472205),
#  (75, 0.0013789542353205627),
#  (76, 0.00044392410991360827),
#  (78, 0.004177054182752995),
#  (80, 0.0020885270913764977),
#  (83, 0.008584765761711249),
#  (84, 0.000510217075990401),
#  (88, 0.0024490419647539255),
#  (89, 0.0033674327015366474),
#  (90, 0.0008878482198272165),
#  (91, 0.001676842475903032),
#  (94, 0.0008878482198272165),
#  (95, 0.00044392410991360827),
#  (96, 0.003551392879308866),
#  (97, 0.0016326946431692835),
#  (102, 0.03773354934265671),
#  (104, 0.0009183907367827219),
#  (106, 0.00141914571211187),
#  (108, 0.0035478642802796744),
#  (109, 0.005306257590300172),
#  (111, 0.002244955134357765),
#  (114, 0.0015306512279712034),
#  (123, 0.05104059366655679),
#  (125, 0.00959208102861954),
#  (126, 0.004177054182752995),
#  (127, 0.00141914571211187),
#  (137, 0.020051661797575882),
#  (139, 0.007759604508918787),
#  (141, 0.001020434151980802),
#  (143, 0.0047573726754963535),
#  (144, 0.004765678634425325),
#  (154, 0.001048026547439395),
#  (156, 0.01397994788213699),
#  (165, 0.006789653945303939),
#  (167, 0.0006122604911884814),
#  (172, 0.021798952186739416),
#  (176, 0.0033674327015366474),
#  (178, 0.0031074687693952584),
#  (186, 0.0092859507830253),
#  (188, 0.001676842475903032),
#  (192, 0.0062655812741294935),
#  (196, 0.0038798022544593936),
#  (197, 0.0013789542353205627),
#  (198, 0.0008878482198272165),
#  (204, 0.00425743713633561),
#  (207, 0.0022632179817679795),
#  (212, 0.001326564397575043),
#  (214, 0.020420509056025982),
#  (215, 0.021748073263001832),
#  (219, 0.0019399011272296968),
#  (220, 0.004401711499245459),
#  (221, 0.0054686350357025125),
#  (222, 0.0018228783452341711),
#  (223, 0.000709572856055935),
#  (224, 0.007713036263850938),
#  (226, 0.0030613024559424068),
#  (230, 0.005142024175900625),
#  (231, 0.0027579084706411254),
#  (235, 0.0024490419647539255),
#  (236, 0.0012932674181531311),
#  (237, 0.00209605309487879),
#  (241, 0.002934474332830306),
#  (242, 0.0015885595448084419),
#  (243, 0.008273725411923376),
#  (245, 0.004526435963535959),
#  (246, 0.0034694761167347273),
#  (247, 0.0017347380583673637),
#  (249, 0.001886447785390911),
#  (251, 0.00835410836550599),
#  (252, 0.0030487254820830752),
#  (253, 0.0006466337090765656),
#  (261, 0.001326564397575043),
#  (269, 0.0006466337090765656),
#  (271, 0.000838421237951516),
#  (276, 0.00993401998478309),
#  (278, 0.0034339063046844994),
#  (280, 0.002128718568167805),
#  (283, 0.021408177039733592),
#  (285, 0.00141914571211187),
#  (287, 0.0013317723297408249),
#  (288, 0.006894771176602813),
#  (290, 0.0035478642802796744),
#  (291, 0.0018228783452341711),
#  (296, 0.009851449545930313),
#  (298, 0.04274758129493744),
#  (300, 0.001676842475903032),
#  (301, 0.0006122604911884814),
#  (302, 0.00425743713633561),
#  (303, 0.004177054182752995),
#  (304, 0.0020885270913764977),
#  (311, 0.0016326946431692835),
#  (313, 0.007095728560559349),
#  (323, 0.004765678634425325),
#  (325, 0.021633204021993008),
#  (327, 0.0017347380583673637),
#  (329, 0.017926405059167313),
#  (335, 0.00044392410991360827),
#  (336, 0.002395196062681588),
#  (338, 0.0020885270913764977),
#  (339, 0.00141914571211187),
#  (344, 0.00141914571211187),
#  (345, 0.011542026857753816),
#  (346, 0.00020408683039616044),
#  (348, 0.0006288159284636369),
#  (349, 0.0006466337090765656),
#  (351, 0.0036457566904683422),
#  (354, 0.007990633978444949),
#  (356, 0.001886447785390911),
#  (358, 0.013789542353205626),
#  (359, 0.0022632179817679795),
#  (362, 0.001016241827361025),
#  (367, 0.002395196062681588),
#  (369, 0.19796793077217406),
#  (370, 0.0437490802856201),
#  (371, 0.000510217075990401),
#  (372, 0.002395196062681588),
#  (373, 0.0016326946431692835),
#  (374, 0.0017347380583673637),
#  (375, 0.0019388248887635242),
#  (376, 0.006497764594124249),
#  (377, 0.0030487254820830752),
#  (380, 0.001616584272691414),
#  (387, 0.000709572856055935),
#  (388, 0.00425743713633561),
#  (389, 0.0005723177174474166),
#  (391, 0.002395196062681588),
#  (400, 0.00203248365472205),
#  (406, 0.013789542353205626),
#  (407, 0.0005723177174474166),
#  (409, 0.003563290261293943),
#  (411, 0.000709572856055935),
#  (412, 0.0047573726754963535),
#  (418, 0.0027579084706411254),
#  (421, 0.0027579084706411254),
#  (424, 0.0075483005960043014),
#  (425, 0.0081299346188882),
#  (426, 0.003233168545382828),
#  (429, 0.0008878482198272165),
#  (431, 0.0008878482198272165),
#  (432, 0.01016241827361025),
#  (433, 0.0016326946431692835),
#  (434, 0.0040649673094441),
#  (436, 0.002128718568167805),
#  (442, 0.009224447128727154),
#  (446, 0.004177054182752995),
#  (448, 0.021589346877251538),
#  (449, 0.03296002310897991),
#  (450, 0.0035478642802796744),
#  (453, 0.0011224775671788824),
#  (454, 0.0040649673094441),
#  (456, 0.011316089908839899),
#  (457, 0.0020885270913764977),
#  (458, 0.0003233168545382828),
#  (463, 0.017926405059167313),
#  (464, 0.0027579084706411254),
#  (465, 0.000857004029316771),
#  (468, 0.00203248365472205),
#  (470, 0.0018228783452341711),
#  (478, 0.010937270071405025),
#  (482, 0.03449095189734856),
#  (484, 0.013789542353205626),
#  (486, 0.0020885270913764977),
#  (489, 0.0054686350357025125),
#  (490, 0.022632179817679798),
#  (491, 0.0040649673094441),
#  (493, 0.000709572856055935),
#  (497, 0.012855060439751563),
#  (498, 0.0035478642802796744),
#  (502, 0.006386155704503415),
#  (505, 0.011985950967667422),
#  (507, 0.0009699505636148484),
#  (514, 0.0025152637138545477),
#  (520, 0.00428582343831937),
#  (524, 0.0020885270913764977),
#  (526, 0.005723177174474167),
#  (527, 0.0027579084706411254),
#  (529, 0.006326691742280973),
#  (531, 0.003551392879308866),
#  (532, 0.012807330322218934),
#  (534, 0.0053270893189632995),
#  (536, 0.0014286078127731233),
#  (541, 0.0011446354348948332),
#  (543, 0.011119916813659095),
#  (544, 0.003144079642318185),
#  (546, 0.0017169531523422497),
#  (551, 0.004790392125363176),
#  (552, 0.0031771190896168837),
#  (558, 0.002395196062681588),
#  (559, 0.00020408683039616044),
#  (561, 0.002244955134357765),
#  (562, 0.005204214175102091),
#  (563, 0.006916975213100006),
#  (564, 0.0011446354348948332),
#  (565, 0.0040649673094441),
#  (566, 0.0013789542353205627),
#  (569, 0.04039709400213835),
#  (573, 0.010643592840839025),
#  (576, 0.0025152637138545477),
#  (578, 0.0028615885872370836),
#  (579, 0.0031633458711404867),
#  (582, 0.0035478642802796744),
#  (586, 0.003568029506622265),
#  (590, 0.001714008058633542),
#  (592, 0.001048026547439395),
#  (593, 0.0018228783452341711),
#  (594, 0.015918772770900515),
#  (596, 0.0015885595448084419),
#  (598, 0.002395196062681588),
#  (600, 0.012531162548258987),
#  (601, 0.00203248365472205),
#  (604, 0.05589330050485638),
#  (605, 0.006386155704503415),
#  (606, 0.0005723177174474166),
#  (616, 0.001048026547439395),
#  (619, 0.007113692791527175),
#  (620, 0.024976206546355857),
#  (626, 0.0013789542353205627),
#  (628, 0.000419210618975758),
#  (629, 0.004203119108997676),
#  (633, 0.0013317723297408249),
#  (635, 0.004967009992391545),
#  (636, 0.005999028205217397),
#  (641, 0.0063542381792337675),
#  (646, 0.0027579084706411254),
#  (649, 0.005771013428876908),
#  (652, 0.0009183907367827219),
#  (653, 0.0011446354348948332),
#  (654, 0.0023786863377481767),
#  (655, 0.001676842475903032),
#  (657, 0.0030487254820830752),
#  (658, 0.007112970799842221),
#  (660, 0.00515085945702675),
#  (662, 0.003568029506622265),
#  (663, 0.0011893431688740884),
#  (665, 0.001016241827361025),
#  (666, 0.006403665161109467),
#  (667, 0.0162598692377764),
#  (668, 0.00567658284844748),
#  (670, 0.011737897331321225),
#  (674, 0.0024490419647539255),
#  (675, 0.04506514153989399),
#  (676, 0.061732838476866336),
#  (678, 0.0004081736607923209),
#  (679, 0.00515085945702675),
#  (681, 0.0007143039063865616),
#  (682, 0.0015885595448084419),
#  (685, 0.0020885270913764977),
#  (686, 0.0006466337090765656),
#  (693, 0.003571519531932808),
#  (698, 0.0022892708697896664),
#  (701, 0.0006122604911884814),
#  (705, 0.003428016117267084),
#  (712, 0.001714008058633542),
#  (713, 0.0013789542353205627),
#  (720, 0.002934474332830306),
#  (722, 0.005081209136805125),
#  (726, 0.017739321401398375),
#  (727, 0.004401711499245459),
#  (728, 0.0031771190896168837),
#  (729, 0.0060974509641661505),
#  (730, 0.0103017189140535),
#  (731, 0.0017169531523422497),
#  (740, 0.008367560046242579),
#  (741, 0.006707369903612128),
#  (743, 0.006938952233469455),
#  (744, 0.010346139345225049),
#  (745, 0.0062655812741294935),
#  (748, 0.017276111065137423),
#  (750, 0.07136059013244529),
#  (752, 0.14617200834752261),
#  (753, 0.06989661997157144),
#  (758, 0.004203119108997676),
#  (769, 0.001714008058633542),
#  (770, 0.001048026547439395),
#  (771, 0.0007143039063865616),
#  (776, 0.000209605309487879),
#  (783, 0.0063542381792337675),
#  (784, 0.004177054182752995),
#  (785, 0.00283829142422374),
#  (786, 0.004177054182752995),
#  (787, 0.006938952233469455),
#  (788, 0.0029592590407443264),
#  (789, 0.003551392879308866),
#  (793, 0.014225941599684442),
#  (797, 0.004203119108997676),
#  (798, 0.024389803856664602),
#  (803, 0.01016241827361025),
#  (805, 0.003428016117267084),
#  (806, 0.02574759837498928),
#  (810, 0.0011893431688740884),
#  (811, 0.006894771176602813),
#  (815, 0.001886447785390911),
#  (816, 0.0012576318569272739),
#  (817, 0.0015885595448084419),
#  (819, 0.0026635446594816497),
#  (820, 0.006466337090765656),
#  (821, 0.006214937538790517),
#  (822, 0.06898190379469712),
#  (825, 0.0003233168545382828),
#  (830, 0.0012245209823769628),
#  (831, 0.0035564853999211104),
#  (832, 0.02259752020860768),
#  (833, 0.010992773054301614),
#  (834, 0.001714008058633542),
#  (838, 0.0019388248887635242),
#  (839, 0.0016326946431692835),
#  (842, 0.0013789542353205627),
#  (848, 0.006894771176602813),
#  (849, 0.0011446354348948332),
#  (851, 0.0020885270913764977),
#  (857, 0.0005723177174474166),
#  (859, 0.00835410836550599),
#  (861, 0.001886447785390911),
#  (862, 0.0017347380583673637),
#  (866, 0.004439241099136083),
#  (867, 0.004790392125363176),
#  (870, 0.0003233168545382828),
#  (873, 0.018886484675764748),
#  (875, 0.0009699505636148484),
#  (878, 0.00203248365472205),
#  (879, 0.005496386527150807),
#  (881, 0.000709572856055935),
#  (883, 0.0008163473215846418),
#  (885, 0.002395196062681588),
#  (887, 0.0017347380583673637),
#  (891, 0.0006466337090765656),
#  (892, 0.0013789542353205627),
#  (894, 0.0024490419647539255),
#  (897, 0.005999028205217397),
#  (898, 0.0011446354348948332),
#  (903, 0.0011893431688740884),
#  (905, 0.0025710120879503125),
#  (909, 0.002653128795150086),
#  (910, 0.005515816941282251),
#  (917, 0.05884366752596747),
#  (919, 0.001714008058633542),
#  (921, 0.0011224775671788824),
#  (924, 0.005408301005498252),
#  (925, 0.004790392125363176),
#  (929, 0.013735625218737998),
#  (931, 0.001016241827361025),
#  (935, 0.0026635446594816497),
#  (936, 0.0025152637138545477),
#  (937, 0.0009699505636148484),
#  (939, 0.0016326946431692835),
#  (944, 0.0008878482198272165),
#  (945, 0.007113692791527175),
#  (948, 0.0023786863377481767),
#  (951, 0.012708476358467535),
#  (952, 0.0060974509641661505),
#  (953, 0.005081209136805125),
#  (956, 0.01016241827361025),
#  (957, 0.0012576318569272739),
#  (958, 0.000857004029316771),
#  (962, 0.0011446354348948332),
#  (966, 0.12769360036819888),
#  (967, 0.047763365885968176),
#  (971, 0.0019399011272296968),
#  (973, 0.000510217075990401),
#  (975, 0.0004081736607923209),
#  (976, 0.002040868303961604),
#  (980, 0.009514745350992707),
#  (981, 0.016547450823846753),
#  (982, 0.001016241827361025),
#  (985, 0.03891760478642433),
#  (988, 0.004387866853517449),
#  (992, 0.0014286078127731233),
#  (994, 0.00794279772404221),
#  (995, 0.021752281385766806),
#  (996, 0.011542026857753816),
#  (997, 0.0022632179817679795),
#  (998, 0.030183164566254576),
#  (999, 0.00953135726885065),
#  (1000, 0.00010204341519808022),
#  (1004, 0.0011893431688740884),
#  (1007, 0.01135316569689496),
#  (1009, 0.004526435963535959),
#  (1010, 0.0034339063046844994),
#  (1012, 0.013211143755693325),
#  (1013, 0.0060974509641661505),
#  (1016, 0.01877598839644676),
#  (1018, 0.005918518081488653),
#  (1019, 0.00020408683039616044),
#  (1020, 0.0007143039063865616),
#  (1022, 0.0022892708697896664),
#  (1023, 0.0012932674181531311),
#  (1024, 0.056056255628418865),
#  (1026, 0.0017169531523422497),
#  (1029, 0.007113692791527175),
#  (1030, 0.0030487254820830752),
#  (1031, 0.0006122604911884814),
#  (1037, 0.000709572856055935),
#  (1039, 0.0005723177174474166),
#  (1042, 0.011119916813659095),
#  (1045, 0.02003112011065958),
#  (1048, 0.007713036263850938),
#  (1050, 0.0015885595448084419),
#  (1053, 0.006867812609368999),
#  (1060, 0.0024490419647539255),
#  (1061, 0.01971109267428573),
#  (1062, 0.004285020146583855),
#  (1065, 0.009652679647243938),
#  (1067, 0.0023786863377481767),
#  (1068, 0.009322406308185774),
#  (1077, 0.0011893431688740884),
#  (1082, 0.004136862705961688),
#  (1083, 0.06982276152858484),
#  (1085, 0.0162598692377764),
#  (1086, 0.025062325096517974),
#  (1087, 0.00141914571211187),
#  (1088, 0.0005723177174474166),
#  (1089, 0.009699505636148483),
#  (1092, 0.11904604420846036),
#  (1093, 0.011119916813659095),
#  (1094, 0.0013789542353205627),
#  (1095, 0.0018228783452341711),
#  (1096, 0.004578541739579333),
#  (1098, 0.0006466337090765656),
#  (1103, 0.0031771190896168837),
#  (1106, 0.004765678634425325),
#  (1107, 0.0022632179817679795),
#  (1108, 0.009605497741664202),
#  (1109, 0.0018228783452341711),
#  (1110, 0.005496386527150807),
#  (1112, 0.001775696439654433),
#  (1115, 0.022063267765129003),
#  (1117, 0.0022632179817679795),
#  (1118, 0.004883165209049691),
#  (1119, 0.0036457566904683422),
#  (1120, 0.01016241827361025),
#  (1122, 0.010704088519866796),
#  (1123, 0.0031771190896168837),
#  (1124, 0.0003233168545382828),
#  (1125, 0.00209605309487879),
#  (1132, 0.0006288159284636369),
#  (1135, 0.0031771190896168837),
#  (1136, 0.0020885270913764977),
#  (1142, 0.0012245209823769628),
#  (1145, 0.0006122604911884814),
#  (1146, 0.001016241827361025),
#  (1148, 0.001326564397575043),
#  (1154, 0.0015885595448084419),
#  (1158, 0.0020885270913764977),
#  (1161, 0.0015885595448084419),
#  (1167, 0.005515816941282251),
#  (1169, 0.00141914571211187),
#  (1173, 0.001775696439654433),
#  (1174, 0.003144079642318185),
#  (1175, 0.0009699505636148484),
#  (1176, 0.0005723177174474166),
#  (1177, 0.002395196062681588),
#  (1179, 0.022063267765129003),
#  (1180, 0.000838421237951516),
#  (1182, 0.0015885595448084419),
#  (1185, 0.000209605309487879),
#  (1186, 0.0027579084706411254),
#  (1187, 0.00141914571211187),
#  (1192, 0.006916975213100006),
#  (1193, 0.007113692791527175),
#  (1196, 0.0032018325805547336),
#  (1198, 0.027354892884104035),
#  (1200, 0.0009699505636148484),
#  (1208, 0.0034339063046844994),
#  (1209, 0.0016326946431692835),
#  (1210, 0.0022632179817679795),
#  (1212, 0.0040649673094441),
#  (1214, 0.0036457566904683422),
#  (1218, 0.000209605309487879),
#  (1223, 0.01831416695831733),
#  (1224, 0.0062655812741294935),
#  (1225, 0.006403665161109467),
#  (1227, 0.0013789542353205627),
#  (1228, 0.004526435963535959),
#  (1229, 0.005240132737196975),
#  (1230, 0.002142911719159685),
#  (1232, 0.008325402182118618),
#  (1234, 0.004177054182752995),
#  (1236, 0.030186839474125364),
#  (1239, 0.0006288159284636369),
#  (1240, 0.0016326946431692835),
#  (1241, 0.000510217075990401),
#  (1245, 0.004285020146583855),
#  (1246, 0.0013789542353205627),
#  (1247, 0.0028615885872370836),
#  (1248, 0.021408177039733592),
#  (1249, 0.000709572856055935),
#  (1251, 0.008273725411923376),
#  (1254, 0.009114391726170856),
#  (1255, 0.12843268694612422),
#  (1257, 0.0027579084706411254),
#  (1258, 0.004006224022131916),
#  (1259, 0.01670821673101198),
#  (1260, 0.0016326946431692835),
#  (1261, 0.002395196062681588),
#  (1264, 0.006497764594124249),
#  (1267, 0.001886447785390911),
#  (1270, 0.0054686350357025125),
#  (1272, 0.000857004029316771),
#  (1273, 0.0016326946431692835),
#  (1275, 0.004387866853517449),
#  (1278, 0.0016326946431692835),
#  (1281, 0.10823022836754204),
#  (1283, 0.005723177174474167),
#  (1284, 0.0015885595448084419),
#  (1285, 0.0022892708697896664),
#  (1286, 0.0012576318569272739),
#  (1290, 0.00425743713633561),
#  (1292, 0.00020408683039616044),
#  (1293, 0.011178660100971275),
#  (1294, 0.0018228783452341711),
#  (1296, 0.0008878482198272165),
#  (1297, 0.003353684951806064),
#  (1300, 0.0006466337090765656),
#  (1301, 0.00515085945702675),
#  (1302, 0.005515816941282251),
#  (1305, 0.001016241827361025),
#  (1307, 0.006789653945303939),
#  (1310, 0.0015306512279712034),
#  (1311, 0.005449738046684854),
#  (1314, 0.02336794208036037),
#  (1315, 0.11353165696894958),
#  (1317, 0.00628815928463637),
#  (1319, 0.011178660100971275),
#  (1320, 0.0027551722103481657),
#  (1322, 0.0011446354348948332),
#  (1323, 0.042031191089976765),
#  (1324, 0.010937270071405025),
#  (1325, 0.0017347380583673637),
#  (1326, 0.000209605309487879),
#  (1327, 0.00020408683039616044),
#  (1328, 0.003563290261293943),
#  (1331, 0.0022196205495680415),
#  (1333, 0.09557705881371857),
#  (1334, 0.000709572856055935),
#  (1335, 0.0031771190896168837),
#  (1336, 0.0015885595448084419),
#  (1337, 0.0012245209823769628),
#  (1338, 0.002128718568167805),
#  (1339, 0.0005723177174474166),
#  (1340, 0.001714008058633542),
#  (1342, 0.0703266660013487),
#  (1346, 0.013789542353205626),
#  (1347, 0.0022632179817679795),
#  (1349, 0.005999028205217397),
#  (1351, 0.0012576318569272739),
#  (1355, 0.0025152637138545477),
#  (1356, 0.0006122604911884814),
#  (1359, 0.0030487254820830752),
#  (1360, 0.001467237166415153),
#  (1363, 0.043178693754503075),
#  (1364, 0.013255991036069595),
#  (1379, 0.0022892708697896664),
#  (1380, 0.0006288159284636369),
#  (1381, 0.0008878482198272165),
#  (1390, 0.00851487427267122),
#  (1393, 0.0006466337090765656),
#  (1396, 0.0011446354348948332),
#  (1402, 0.000709572856055935),
#  (1406, 0.0020885270913764977),
#  (1407, 0.008434558088358557),
#  (1410, 0.0011446354348948332),
#  (1411, 0.003233168545382828),
#  (1414, 0.00141914571211187),
#  (1416, 0.0023786863377481767),
#  (1418, 0.0012245209823769628),
#  (1423, 0.0053270893189632995),
#  (1425, 0.0022892708697896664),
#  (1426, 0.0025710120879503125),
#  (1428, 0.026829479614448513),
#  (1430, 0.023442222000449566),
#  (1433, 0.006295494891921584),
#  (1439, 0.0027579084706411254),
#  (1441, 0.0036457566904683422),
#  (1442, 0.002395196062681588),
#  (1443, 0.0013789542353205627),
#  (1445, 0.03847470569005565),
#  (1449, 0.0031771190896168837),
#  (1450, 0.000838421237951516),
#  (1451, 0.000857004029316771),
#  (1457, 0.005408301005498252),
#  (1464, 0.004883165209049691),
#  (1465, 0.0017169531523422497),
#  (1471, 0.03132732846581063),
#  (1476, 0.0032018325805547336),
#  (1478, 0.0025710120879503125),
#  (1480, 0.0009183907367827219),
#  (1482, 0.0062655812741294935),
#  (1488, 0.0011446354348948332),
#  (1489, 0.0051730696726125245),
#  (1492, 0.0071855881880447635),
#  (1493, 0.001048026547439395),
#  (1497, 0.006894771176602813),
#  (1500, 0.000510217075990401),
#  (1502, 0.005081209136805125),
#  (1503, 0.0027551722103481657),
#  (1506, 0.024853116850186357),
#  (1520, 0.002724869023342427),
#  (1523, 0.016547450823846753),
#  (1524, 0.07308600417376131),
#  (1525, 0.004177054182752995),
#  (1530, 0.0023786863377481767),
#  (1532, 0.0036457566904683422),
#  (1533, 0.0023786863377481767),
#  (1534, 0.002128718568167805),
#  (1535, 0.000838421237951516),
#  (1536, 0.02412547710590179),
#  (1540, 0.0013789542353205627),
#  (1541, 0.008584765761711249),
#  (1542, 0.0014286078127731233),
#  (1543, 0.009322406308185774),
#  (1544, 0.003233168545382828),
#  (1546, 0.009580784250726351),
#  (1548, 0.006403665161109467),
#  (1552, 0.016122859601296675),
#  (1554, 0.017840147533111323),
#  (1557, 0.0013789542353205627),
#  (1559, 0.0017347380583673637),
#  (1561, 0.005918518081488653),
#  (1566, 0.004967009992391545),
#  (1568, 0.013789542353205626),
#  (1572, 0.0015885595448084419),
#  (1576, 0.0016326946431692835),
#  (1577, 0.00020408683039616044),
#  (1578, 0.0006122604911884814),
#  (1581, 0.012429875077581034),
#  (1583, 0.004765678634425325),
#  (1587, 0.0017169531523422497),
#  (1588, 0.0013789542353205627),
#  (1589, 0.004177054182752995),
#  (1590, 0.0020885270913764977),
#  (1598, 0.0004081736607923209),
#  (1601, 0.0022196205495680415),
#  (1605, 0.0023786863377481767),
#  (1607, 0.0034339063046844994),
#  (1609, 0.004790392125363176),
#  (1613, 0.005723177174474167),
#  (1616, 0.008273725411923376),
#  (1619, 0.000857004029316771),
#  (1624, 0.005142024175900625),
#  (1625, 0.017276111065137423),
#  (1627, 0.0011446354348948332),
#  (1628, 0.04063455793876658),
#  (1629, 0.0024490419647539255),
#  (1635, 0.007713036263850938),
#  (1636, 0.003568029506622265),
#  (1637, 0.013789542353205626),
#  (1640, 0.009114391726170856),
#  (1642, 0.0035478642802796744),
#  (1643, 0.0034339063046844994),
#  (1644, 0.0020885270913764977),
#  (1646, 0.0062655812741294935),
#  (1647, 0.0014286078127731233),
#  (1648, 0.005999028205217397),
#  (1649, 0.000510217075990401),
#  (1650, 0.0012576318569272739),
#  (1655, 0.003265389286338567),
#  (1657, 0.010000254689411863),
#  (1661, 0.001676842475903032),
#  (1665, 0.0027551722103481657),
#  (1666, 0.0015306512279712034),
#  (1667, 0.0012932674181531311),
#  (1668, 0.0047573726754963535),
#  (1670, 0.03720065163408208),
#  (1677, 0.0015306512279712034),
#  (1680, 0.001020434151980802),
#  (1684, 0.008273725411923376),
#  (1686, 0.001467237166415153),
#  (1692, 0.0008163473215846418),
#  (1695, 0.0012932674181531311),
#  (1696, 0.012194901928332301),
#  (1701, 0.005142024175900625),
#  (1705, 0.0026635446594816497),
#  (1708, 0.003563290261293943),
#  (1710, 0.0012245209823769628),
#  (1712, 0.0003061302455942407),
#  (1715, 0.0011893431688740884),
#  (1716, 0.0017347380583673637),
#  (1719, 0.0003233168545382828),
#  (1722, 0.0027579084706411254),
#  (1727, 0.0011446354348948332),
#  (1728, 0.10585154202979385),
#  (1735, 0.00203248365472205),
#  (1743, 0.00209605309487879),
#  (1744, 0.0009699505636148484),
#  (1752, 0.026635446594816495),
#  (1754, 0.0072915133809366844),
#  (1759, 0.008273725411923376),
#  (1761, 0.003144079642318185),
#  (1762, 0.000838421237951516),
#  (1763, 0.005946715844370442),
#  (1766, 0.001467237166415153),
#  (1768, 0.0071855881880447635),
#  (1770, 0.0023786863377481767),
#  (1772, 0.016283076557018647),
#  (1774, 0.0031771190896168837),
#  (1775, 0.0054686350357025125),
#  (1778, 0.006867812609368999),
#  (1779, 0.0072915133809366844),
#  (1780, 0.001048026547439395),
#  (1781, 0.00283829142422374),
#  (1782, 0.004967009992391545),
#  (1784, 0.0027579084706411254),
#  (1785, 0.006403665161109467),
#  (1793, 0.0020885270913764977),
#  (1794, 0.000857004029316771),
#  (1797, 0.01885408864496896),
#  (1798, 0.021122986946002606),
#  (1799, 0.004765678634425325),
#  (1806, 0.0029592590407443264),
#  (1808, 0.0063542381792337675),
#  (1813, 0.00044392410991360827),
#  (1815, 0.0013789542353205627),
#  (1816, 0.0013789542353205627),
#  (1820, 0.0023786863377481767),
#  (1823, 0.00857004029316771),
#  (1825, 0.0054686350357025125),
#  (1832, 0.0011224775671788824),
#  (1833, 0.0031074687693952584),
#  (1834, 0.000838421237951516),
#  (1835, 0.000709572856055935),
#  (1838, 0.0005723177174474166),
#  (1840, 0.0006288159284636369),
#  (1841, 0.0015885595448084419),
#  (1846, 0.006894771176602813),
#  (1847, 0.00515085945702675),
#  (1848, 0.009652679647243938),
#  (1849, 0.001020434151980802),
#  (1850, 0.005515816941282251),
#  (1851, 0.00942704432248448),
#  (1853, 0.01714008058633542),
#  (1854, 0.001714008058633542),
#  (1857, 0.004387866853517449),
#  (1858, 0.0029098516908445454),
#  (1859, 0.04183780023121289),
#  (1860, 0.0035564853999211104),
#  (1862, 0.007113692791527175),
#  (1864, 0.002128718568167805),
#  (1866, 0.004136862705961688),
#  (1869, 0.0063542381792337675),
#  (1876, 0.000209605309487879),
#  (1878, 0.0737023465212423),
#  (1881, 0.020051661797575882),
#  (1884, 0.0060974509641661505),
#  (1885, 0.008584765761711249),
#  (1898, 0.005819703381689091),
#  (1899, 0.0027579084706411254),
#  (1904, 0.005515816941282251),
#  (1905, 0.005142024175900625),
#  (1906, 0.000857004029316771),
#  (1907, 0.0006466337090765656),
#  (1908, 0.0004081736607923209),
#  (1909, 0.003428016117267084),
#  (1910, 0.0027579084706411254),
#  (1915, 0.002395196062681588),
#  (1916, 0.0013317723297408249),
#  (1922, 0.012531162548258987),
#  (1923, 0.0031771190896168837),
#  (1926, 0.0025710120879503125),
#  (1933, 0.0018367814735654438),
#  (1934, 0.0003061302455942407),
#  (1935, 0.007713036263850938),
#  (1938, 0.006214937538790517),
#  (1940, 0.006856032234534168),
#  (1941, 0.003353684951806064),
#  (1942, 0.00010204341519808022),
#  (1944, 0.0011893431688740884),
#  (1945, 0.0012576318569272739),
#  (1948, 0.0005723177174474166),
#  (1949, 0.005000127344705931),
#  (1951, 0.010704088519866796),
#  (1952, 0.0023786863377481767),
#  (1953, 0.0027579084706411254),
#  (1958, 0.004790392125363176),
#  (1959, 0.000209605309487879),
#  (1964, 0.0072915133809366844),
#  (1965, 0.001016241827361025),
#  (1966, 0.010992773054301614),
#  (1967, 0.005000127344705931),
#  (1968, 0.005142024175900625),
#  (1974, 0.014191457121118698),
#  (1979, 0.002128718568167805),
#  (1980, 0.004285020146583855),
#  (1981, 0.002040868303961604),
#  (1982, 0.0013789542353205627),
#  (1985, 0.01588559544808442),
#  (1986, 0.061704290110807504),
#  (1990, 0.01197598031340794),
#  (1991, 0.0003233168545382828),
#  (1993, 0.02068431352980844),
#  (1994, 0.009146176446249226),
#  (1997, 0.0025865348363062622),
#  (2000, 0.0025152637138545477),
#  (2001, 0.0007143039063865616),
#  (2002, 0.0017347380583673637),
#  (2003, 0.001016241827361025),
#  (2007, 0.0016326946431692835),
#  (2010, 0.003982500880269701),
#  (2012, 0.013624345116712134),
#  (2013, 0.0013317723297408249),
#  (2014, 0.0011224775671788824),
#  (2018, 0.00141914571211187),
#  (2020, 0.0016326946431692835),
#  (2021, 0.001714008058633542),
#  (2022, 0.008265516631044498),
#  (2023, 0.0005723177174474166),
#  (2026, 0.004820922118221217),
#  (2030, 0.0005723177174474166),
#  (2031, 0.0018228783452341711),
#  (2032, 0.0020885270913764977),
#  (2037, 0.0005723177174474166),
#  (2039, 0.013255991036069595),
#  (2044, 0.005946715844370442),
#  (2045, 0.001048026547439395),
#  (2049, 0.0035478642802796744),
#  (2051, 0.0008163473215846418),
#  (2053, 0.003568029506622265),
#  (2054, 0.0008878482198272165),
#  (2055, 0.0017347380583673637),
#  (2065, 0.0018367814735654438),
#  (2066, 0.0005723177174474166),
#  (2067, 0.00993401998478309),
#  (2068, 0.0020885270913764977),
#  (2069, 0.0005723177174474166),
#  (2073, 0.0047573726754963535),
#  (2074, 0.001016241827361025),
#  (2076, 0.0031074687693952584),
#  (2078, 0.0015885595448084419),
#  (2082, 0.0011893431688740884),
#  (2083, 0.001467237166415153),
#  (2084, 0.0011446354348948332),
#  (2086, 0.0054686350357025125),
#  (2087, 0.011318686712345467),
#  (2088, 0.0003233168545382828),
#  (2089, 0.0009183907367827219),
#  (2090, 0.0032018325805547336),
#  (2095, 0.0013789542353205627),
#  (2096, 0.0008878482198272165),
#  (2102, 0.0027579084706411254),
#  (2108, 0.004177054182752995),
#  (2110, 0.000857004029316771),
#  (2111, 0.0009183907367827219),
#  (2114, 0.007095728560559349),
#  (2116, 0.0023786863377481767),
#  (2117, 0.004136862705961688),
#  (2118, 0.02068431352980844),
#  (2119, 0.004849752818074242),
#  (2125, 0.0011893431688740884),
#  (2127, 0.002395196062681588),
#  (2128, 0.005946715844370442),
#  (2133, 0.00141914571211187),
#  (2134, 0.0038798022544593936),
#  (2135, 0.0020885270913764977),
#  (2136, 0.00794279772404221),
#  (2138, 0.002128718568167805),
#  (2144, 0.039444656253670496),
#  (2145, 0.00141914571211187),
#  (2148, 0.002244955134357765),
#  (2152, 0.002305658404366669),
#  (2154, 0.0014286078127731233),
#  (2155, 0.0054686350357025125),
#  (2156, 0.04136862705961688),
#  (2158, 0.07768671923488145),
#  (2159, 0.024389803856664602),
#  (2162, 0.014307942936185414),
#  (2164, 0.32782265949784195),
#  (2165, 0.007546709868531341),
#  (2169, 0.0025510853799520054),
#  (2170, 0.0012932674181531311),
#  (2172, 0.00203248365472205),
#  (2176, 0.0060974509641661505),
#  (2180, 0.002934474332830306),
#  (2183, 0.0026635446594816497),
#  (2186, 0.02861588587237083),
#  (2187, 0.045421213553788864),
#  (2195, 0.013735625218737998),
#  (2197, 0.02841114303447093),
#  (2200, 0.000709572856055935),
#  (2202, 0.0013789542353205627),
#  (2206, 0.01659721380597508),
#  (2208, 0.001016241827361025),
#  (2210, 0.02620013047109069),
#  (2222, 0.0018228783452341711),
#  (2223, 0.0018228783452341711),
#  (2226, 0.002142911719159685),
#  (2227, 0.00203248365472205),
#  (2229, 0.0054686350357025125),
#  (2232, 0.00010204341519808022),
#  (2233, 0.0024490419647539255),
#  (2234, 0.0063542381792337675),
#  (2235, 0.004765678634425325),
#  (2237, 0.000419210618975758),
#  (2238, 0.00020408683039616044),
#  (2240, 0.0012932674181531311),
#  (2241, 0.009652679647243938),
#  (2242, 0.00283829142422374),
#  (2244, 0.07446352870731038),
#  (2249, 0.0008878482198272165),
#  (2250, 0.0022196205495680415),
#  (2255, 0.005723177174474167),
#  (2258, 0.002395196062681588),
#  (2264, 0.0003061302455942407),
#  (2266, 0.0020885270913764977),
#  (2267, 0.004611316808733338),
#  (2272, 0.004136862705961688),
#  (2273, 0.004177054182752995),
#  (2274, 0.0027551722103481657),
#  (2277, 0.002128718568167805),
#  (2279, 0.002395196062681588),
#  (2280, 0.0051730696726125245),
#  (2281, 0.000838421237951516),
#  (2282, 0.0017347380583673637),
#  (2284, 0.013082774857614972),
#  (2285, 0.0023786863377481767),
#  (2289, 0.006428735157479055),
#  (2290, 0.005306257590300172),
#  (2292, 0.004285020146583855),
#  (2294, 0.0015885595448084419),
#  (2296, 0.0015885595448084419),
#  (2297, 0.000419210618975758),
#  (2300, 0.004006224022131916),
#  (2302, 0.009114391726170856),
#  (2303, 0.002040868303961604),
#  (2305, 0.005515816941282251),
#  (2309, 0.01422738558305435),
#  (2311, 0.008273725411923376),
#  (2313, 0.007440130326816416),
#  (2315, 0.0008878482198272165),
#  (2317, 0.002244955134357765),
#  (2319, 0.0022892708697896664),
#  (2320, 0.0031074687693952584),
#  (2322, 0.003995316989222474),
#  (2325, 0.14837130679470964),
#  (2328, 0.001016241827361025),
#  (2330, 0.04292382880855625),
#  (2332, 0.00209605309487879),
#  (2335, 0.004006224022131916),
#  (2336, 0.011178660100971275),
#  (2337, 0.0031771190896168837),
#  (2339, 0.0030613024559424068),
#  (2340, 0.03723176435365519),
#  (2342, 0.001467237166415153),
#  (2343, 0.0025710120879503125),
#  (2344, 0.001467237166415153),
#  (2346, 0.004967009992391545),
#  (2349, 0.003428016117267084),
#  (2352, 0.0013317723297408249),
#  (2353, 0.0009699505636148484),
#  (2357, 0.0688285670374257),
#  (2359, 0.0015885595448084419),
#  (2361, 0.002653128795150086),
#  (2363, 0.0006466337090765656),
#  (2364, 0.0074491693094598565),
#  (2368, 0.027438529338747675),
#  (2369, 0.00425743713633561),
#  (2370, 0.0013789542353205627),
#  (2375, 0.007990633978444949),
#  (2376, 0.0031633458711404867),
#  (2377, 0.0030613024559424068),
#  (2378, 0.008584765761711249),
#  (2381, 0.00203248365472205),
#  (2382, 0.001676842475903032),
#  (2383, 0.0008878482198272165),
#  (2385, 0.0006466337090765656),
#  (2387, 0.0003233168545382828),
#  (2389, 0.00425743713633561),
#  (2392, 0.0006288159284636369),
#  (2393, 0.002040868303961604),
#  (2396, 0.0062655812741294935),
#  (2399, 0.011098102747840208),
#  (2401, 0.001016241827361025),
#  (2408, 0.01655881944954244),
#  (2409, 0.019029490701985414),
#  (2417, 0.000709572856055935),
#  (2418, 0.004136862705961688),
#  (2419, 0.0013789542353205627),
#  (2420, 0.0013317723297408249),
#  (2421, 0.010654178637926599),
#  (2422, 0.014205571517235465),
#  (2423, 0.0019399011272296968),
#  (2431, 0.0005723177174474166),
#  (2432, 0.0031633458711404867),
#  (2433, 0.00010204341519808022),
#  (2434, 0.00209605309487879),
#  (2444, 0.0005723177174474166),
#  ...]

# %% [markdown]
# ## 9. The results of the tf-idf model
# <p>Once again, the format of those results is hard to interpret for a human. Therefore, we will transform it into a more readable version and display the 10 most specific words for the "<em>On the Origin of Species</em>" book.</p>

# %%
# Convert the tf-idf model for "On the Origin of Species" into a DataFrame
df_tfidf = pd.DataFrame(model[bows[ori]])

# Name the columns of the DataFrame id and score
# ... YOUR CODE FOR TASK 9 ...
df_tfidf.columns = ['id', 'score']

# Add the tokens corresponding to the numerical indices for better readability
# ... YOUR CODE FOR TASK 9 ...
df_tfidf['token'] = [dictionary[i] for i in list(df_tfidf["id"])]

# Sort the DataFrame by descending tf-idf score and print the first 10 rows.
# ... YOUR CODE FOR TASK 9 ...
df_tfidf.sort_values(by="score", ascending=False).head(10)
# Out:
#          id     score      token
# 880    2164  0.327823     select
# 3103  10108  0.204162     pigeon
# 128     369  0.197968      breed
# 2985   9395  0.167705     migrat
# 947    2325  0.148371     steril
# 285     752  0.146172     domest
# 504    1255  0.128433     hybrid
# 371     966  0.127694     fertil
# 3840  16046  0.124547    gärtner
# 3536  12729  0.121348  naturalis

# %% [markdown]
# ## 10. Compute distance between texts
# <p>The results of the tf-idf algorithm now return stemmed tokens which are specific to each book. We can, for example, see that topics such as selection, breeding or domestication are defining "<em>On the Origin of Species</em>" (and yes, in this book, Charles Darwin talks quite a lot about pigeons too). Now that we have a model associating tokens to how specific they are to each book, we can measure how related to books are between each other.</p>
# <p>To this purpose, we will use a measure of similarity called <strong>cosine similarity</strong> and we will visualize the results as a distance matrix, i.e., a matrix showing all pairwise distances between Darwin's books.</p>

# %%
# Load the library allowing similarity computations
from gensim import similarities as sm

# Compute the similarity matrix (pairwise distance between all texts)
sims = sm.MatrixSimilarity(model[bows])

# Transform the resulting list into a dataframe
sim_df = pd.DataFrame(list(sims))

# Add the titles of the books as columns and index of the dataframe
# ... YOUR CODE FOR TASK 10 ..
sim_df.columns = titles
sim_df.index = titles

# Print the resulting matrix
# ... YOUR CODE FOR TASK 10 
sim_df
# Out:
#                                      Autobiography  CoralReefs  DescentofMan  \
# Autobiography                             1.000000    0.049722      0.080789
# CoralReefs                                0.049722    1.000000      0.009516
# DescentofMan                              0.080789    0.009516      1.000000
# DifferentFormsofFlowers                   0.066615    0.001980      0.072792
# EffectsCrossSelfFertilization             0.077006    0.001936      0.029997
# ExpressionofEmotionManAnimals             0.089345    0.005062      0.148642
# FormationVegetableMould                   0.041182    0.029445      0.027106
# FoundationsOriginofSpecies                0.058990    0.022066      0.135001
# GeologicalObservationsSouthAmerica        0.030679    0.060744      0.009628
# InsectivorousPlants                       0.014945    0.002284      0.009468
# LifeandLettersVol1                        0.399534    0.031211      0.060040
# LifeandLettersVol2                        0.220023    0.017772      0.080569
# MonographCirripedia                       0.005854    0.006321      0.053426
# MonographCirripediaVol2                   0.008456    0.010497      0.042937
# MovementClimbingPlants                    0.022999    0.001534      0.005157
# OriginofSpecies                           0.101199    0.039200      0.267734
# PowerMovementPlants                       0.016059    0.002686      0.011267
# VariationPlantsAnimalsDomestication       0.048989    0.011383      0.228437
# VolcanicIslands                           0.038630    0.057402      0.007885
# VoyageBeagle                              0.184288    0.267414      0.123902
#
#                                      DifferentFormsofFlowers  \
# Autobiography                                       0.066615
# CoralReefs                                          0.001980
# DescentofMan                                        0.072792
# DifferentFormsofFlowers                             1.000000
# EffectsCrossSelfFertilization                       0.391788
# ExpressionofEmotionManAnimals                       0.006545
# FormationVegetableMould                             0.010621
# FoundationsOriginofSpecies                          0.039993
# GeologicalObservationsSouthAmerica                  0.002855
# InsectivorousPlants                                 0.007487
# LifeandLettersVol1                                  0.016188
# LifeandLettersVol2                                  0.046692
# MonographCirripedia                                 0.009403
# MonographCirripediaVol2                             0.005451
# MovementClimbingPlants                              0.008165
# OriginofSpecies                                     0.129152
# PowerMovementPlants                                 0.018831
# VariationPlantsAnimalsDomestication                 0.049405
# VolcanicIslands                                     0.002624
# VoyageBeagle                                        0.013213
#
#                                      EffectsCrossSelfFertilization  \
# Autobiography                                             0.077006
# CoralReefs                                                0.001936
# DescentofMan                                              0.029997
# DifferentFormsofFlowers                                   0.391788
# EffectsCrossSelfFertilization                             1.000000
# ExpressionofEmotionManAnimals                             0.006871
# FormationVegetableMould                                   0.032270
# FoundationsOriginofSpecies                                0.040248
# GeologicalObservationsSouthAmerica                        0.002247
# InsectivorousPlants                                       0.006763
# LifeandLettersVol1                                        0.019609
# LifeandLettersVol2                                        0.046567
# MonographCirripedia                                       0.003218
# MonographCirripediaVol2                                   0.002957
# MovementClimbingPlants                                    0.014939
# OriginofSpecies                                           0.146700
# PowerMovementPlants                                       0.039520
# VariationPlantsAnimalsDomestication                       0.054458
# VolcanicIslands                                           0.002183
# VoyageBeagle                                              0.017183
#
#                                      ExpressionofEmotionManAnimals  \
# Autobiography                                             0.089345
# CoralReefs                                                0.005062
# DescentofMan                                              0.148642
# DifferentFormsofFlowers                                   0.006545
# EffectsCrossSelfFertilization                             0.006871
# ExpressionofEmotionManAnimals                             1.000000
# FormationVegetableMould                                   0.021066
# FoundationsOriginofSpecies                                0.047103
# GeologicalObservationsSouthAmerica                        0.005246
# InsectivorousPlants                                       0.011461
# LifeandLettersVol1                                        0.065391
# LifeandLettersVol2                                        0.049333
# MonographCirripedia                                       0.016802
# MonographCirripediaVol2                                   0.029644
# MovementClimbingPlants                                    0.005942
# OriginofSpecies                                           0.063242
# PowerMovementPlants                                       0.011234
# VariationPlantsAnimalsDomestication                       0.082567
# VolcanicIslands                                           0.005595
# VoyageBeagle                                              0.099124
#
#                                      FormationVegetableMould  \
# Autobiography                                       0.041182
# CoralReefs                                          0.029445
# DescentofMan                                        0.027106
# DifferentFormsofFlowers                             0.010621
# EffectsCrossSelfFertilization                       0.032270
# ExpressionofEmotionManAnimals                       0.021066
# FormationVegetableMould                             1.000000
# FoundationsOriginofSpecies                          0.021468
# GeologicalObservationsSouthAmerica                  0.067712
# InsectivorousPlants                                 0.035498
# LifeandLettersVol1                                  0.028357
# LifeandLettersVol2                                  0.023943
# MonographCirripedia                                 0.019864
# MonographCirripediaVol2                             0.023915
# MovementClimbingPlants                              0.038823
# OriginofSpecies                                     0.049519
# PowerMovementPlants                                 0.039911
# VariationPlantsAnimalsDomestication                 0.032647
# VolcanicIslands                                     0.059299
# VoyageBeagle                                        0.098331
#
#                                      FoundationsOriginofSpecies  \
# Autobiography                                          0.058990
# CoralReefs                                             0.022066
# DescentofMan                                           0.135001
# DifferentFormsofFlowers                                0.039993
# EffectsCrossSelfFertilization                          0.040248
# ExpressionofEmotionManAnimals                          0.047103
# FormationVegetableMould                                0.021468
# FoundationsOriginofSpecies                             1.000000
# GeologicalObservationsSouthAmerica                     0.027300
# InsectivorousPlants                                    0.005995
# LifeandLettersVol1                                     0.057749
# LifeandLettersVol2                                     0.054703
# MonographCirripedia                                    0.007650
# MonographCirripediaVol2                                0.010762
# MovementClimbingPlants                                 0.003971
# OriginofSpecies                                        0.322736
# PowerMovementPlants                                    0.008712
# VariationPlantsAnimalsDomestication                    0.196578
# VolcanicIslands                                        0.017528
# VoyageBeagle                                           0.089075
#
#                                      GeologicalObservationsSouthAmerica  \
# Autobiography                                                  0.030679
# CoralReefs                                                     0.060744
# DescentofMan                                                   0.009628
# DifferentFormsofFlowers                                        0.002855
# EffectsCrossSelfFertilization                                  0.002247
# ExpressionofEmotionManAnimals                                  0.005246
# FormationVegetableMould                                        0.067712
# FoundationsOriginofSpecies                                     0.027300
# GeologicalObservationsSouthAmerica                             1.000000
# InsectivorousPlants                                            0.006844
# LifeandLettersVol1                                             0.028691
# LifeandLettersVol2                                             0.012241
# MonographCirripedia                                            0.009260
# MonographCirripediaVol2                                        0.023486
# MovementClimbingPlants                                         0.002046
# OriginofSpecies                                                0.052878
# PowerMovementPlants                                            0.003450
# VariationPlantsAnimalsDomestication                            0.013737
# VolcanicIslands                                                0.372272
# VoyageBeagle                                                   0.259514
#
#                                      InsectivorousPlants  LifeandLettersVol1  \
# Autobiography                                   0.014945            0.399534
# CoralReefs                                      0.002284            0.031211
# DescentofMan                                    0.009468            0.060040
# DifferentFormsofFlowers                         0.007487            0.016188
# EffectsCrossSelfFertilization                   0.006763            0.019609
# ExpressionofEmotionManAnimals                   0.011461            0.065391
# FormationVegetableMould                         0.035498            0.028357
# FoundationsOriginofSpecies                      0.005995            0.057749
# GeologicalObservationsSouthAmerica              0.006844            0.028691
# InsectivorousPlants                             1.000000            0.006062
# LifeandLettersVol1                              0.006062            1.000000
# LifeandLettersVol2                              0.016549            0.885953
# MonographCirripedia                             0.019091            0.005839
# MonographCirripediaVol2                         0.019657            0.012716
# MovementClimbingPlants                          0.249011            0.005533
# OriginofSpecies                                 0.014982            0.098352
# PowerMovementPlants                             0.022841            0.009439
# VariationPlantsAnimalsDomestication             0.010321            0.054805
# VolcanicIslands                                 0.008526            0.026517
# VoyageBeagle                                    0.014758            0.172502
#
#                                      LifeandLettersVol2  MonographCirripedia  \
# Autobiography                                  0.220023             0.005854
# CoralReefs                                     0.017772             0.006321
# DescentofMan                                   0.080569             0.053426
# DifferentFormsofFlowers                        0.046692             0.009403
# EffectsCrossSelfFertilization                  0.046567             0.003218
# ExpressionofEmotionManAnimals                  0.049333             0.016802
# FormationVegetableMould                        0.023943             0.019864
# FoundationsOriginofSpecies                     0.054703             0.007650
# GeologicalObservationsSouthAmerica             0.012241             0.009260
# InsectivorousPlants                            0.016549             0.019091
# LifeandLettersVol1                             0.885953             0.005839
# LifeandLettersVol2                             1.000000             0.004961
# MonographCirripedia                            0.004961             1.000000
# MonographCirripediaVol2                        0.010570             0.516038
# MovementClimbingPlants                         0.017673             0.012450
# OriginofSpecies                                0.097736             0.031278
# PowerMovementPlants                            0.012017             0.018565
# VariationPlantsAnimalsDomestication            0.050260             0.022999
# VolcanicIslands                                0.011930             0.010054
# VoyageBeagle                                   0.090674             0.014269
#
#                                      MonographCirripediaVol2  \
# Autobiography                                       0.008456
# CoralReefs                                          0.010497
# DescentofMan                                        0.042937
# DifferentFormsofFlowers                             0.005451
# EffectsCrossSelfFertilization                       0.002957
# ExpressionofEmotionManAnimals                       0.029644
# FormationVegetableMould                             0.023915
# FoundationsOriginofSpecies                          0.010762
# GeologicalObservationsSouthAmerica                  0.023486
# InsectivorousPlants                                 0.019657
# LifeandLettersVol1                                  0.012716
# LifeandLettersVol2                                  0.010570
# MonographCirripedia                                 0.516038
# MonographCirripediaVol2                             1.000000
# MovementClimbingPlants                              0.006762
# OriginofSpecies                                     0.037865
# PowerMovementPlants                                 0.022154
# VariationPlantsAnimalsDomestication                 0.029694
# VolcanicIslands                                     0.016404
# VoyageBeagle                                        0.024734
#
#                                      MovementClimbingPlants  OriginofSpecies  \
# Autobiography                                      0.022999         0.101199
# CoralReefs                                         0.001534         0.039200
# DescentofMan                                       0.005157         0.267734
# DifferentFormsofFlowers                            0.008165         0.129152
# EffectsCrossSelfFertilization                      0.014939         0.146700
# ExpressionofEmotionManAnimals                      0.005942         0.063242
# FormationVegetableMould                            0.038823         0.049519
# FoundationsOriginofSpecies                         0.003971         0.322736
# GeologicalObservationsSouthAmerica                 0.002046         0.052878
# InsectivorousPlants                                0.249011         0.014982
# LifeandLettersVol1                                 0.005533         0.098352
# LifeandLettersVol2                                 0.017673         0.097736
# MonographCirripedia                                0.012450         0.031278
# MonographCirripediaVol2                            0.006762         0.037865
# MovementClimbingPlants                             1.000000         0.008858
# OriginofSpecies                                    0.008858         1.000000
# PowerMovementPlants                                0.104310         0.018170
# VariationPlantsAnimalsDomestication                0.011361         0.404093
# VolcanicIslands                                    0.002842         0.035924
# VoyageBeagle                                       0.012328         0.165247
#
#                                      PowerMovementPlants  \
# Autobiography                                   0.016059
# CoralReefs                                      0.002686
# DescentofMan                                    0.011267
# DifferentFormsofFlowers                         0.018831
# EffectsCrossSelfFertilization                   0.039520
# ExpressionofEmotionManAnimals                   0.011234
# FormationVegetableMould                         0.039911
# FoundationsOriginofSpecies                      0.008712
# GeologicalObservationsSouthAmerica              0.003450
# InsectivorousPlants                             0.022841
# LifeandLettersVol1                              0.009439
# LifeandLettersVol2                              0.012017
# MonographCirripedia                             0.018565
# MonographCirripediaVol2                         0.022154
# MovementClimbingPlants                          0.104310
# OriginofSpecies                                 0.018170
# PowerMovementPlants                             1.000000
# VariationPlantsAnimalsDomestication             0.020184
# VolcanicIslands                                 0.003787
# VoyageBeagle                                    0.023967
#
#                                      VariationPlantsAnimalsDomestication  \
# Autobiography                                                   0.048989
# CoralReefs                                                      0.011383
# DescentofMan                                                    0.228437
# DifferentFormsofFlowers                                         0.049405
# EffectsCrossSelfFertilization                                   0.054458
# ExpressionofEmotionManAnimals                                   0.082567
# FormationVegetableMould                                         0.032647
# FoundationsOriginofSpecies                                      0.196578
# GeologicalObservationsSouthAmerica                              0.013737
# InsectivorousPlants                                             0.010321
# LifeandLettersVol1                                              0.054805
# LifeandLettersVol2                                              0.050260
# MonographCirripedia                                             0.022999
# MonographCirripediaVol2                                         0.029694
# MovementClimbingPlants                                          0.011361
# OriginofSpecies                                                 0.404093
# PowerMovementPlants                                             0.020184
# VariationPlantsAnimalsDomestication                             1.000000
# VolcanicIslands                                                 0.012210
# VoyageBeagle                                                    0.112421
#
#                                      VolcanicIslands  VoyageBeagle
# Autobiography                               0.038630      0.184288
# CoralReefs                                  0.057402      0.267414
# DescentofMan                                0.007885      0.123902
# DifferentFormsofFlowers                     0.002624      0.013213
# EffectsCrossSelfFertilization               0.002183      0.017183
# ExpressionofEmotionManAnimals               0.005595      0.099124
# FormationVegetableMould                     0.059299      0.098331
# FoundationsOriginofSpecies                  0.017528      0.089075
# GeologicalObservationsSouthAmerica          0.372272      0.259514
# InsectivorousPlants                         0.008526      0.014758
# LifeandLettersVol1                          0.026517      0.172502
# LifeandLettersVol2                          0.011930      0.090674
# MonographCirripedia                         0.010054      0.014269
# MonographCirripediaVol2                     0.016404      0.024734
# MovementClimbingPlants                      0.002842      0.012328
# OriginofSpecies                             0.035924      0.165247
# PowerMovementPlants                         0.003787      0.023967
# VariationPlantsAnimalsDomestication         0.012210      0.112421
# VolcanicIslands                             1.000000      0.138035
# VoyageBeagle                                0.138035      1.000000

# %% [markdown]
# ## 11. The book most similar to "On the Origin of Species"
# <p>We now have a matrix containing all the similarity measures between any pair of books from Charles Darwin! We can now use this matrix to quickly extract the information we need, i.e., the distance between one book and one or several others. </p>
# <p>As a first step, we will display which books are the most similar to "<em>On the Origin of Species</em>," more specifically we will produce a bar chart showing all books ranked by how similar they are to Darwin's landmark work.</p>

# %%
# This is needed to display plots in a notebook
# %matplotlib inline

# Import libraries
import matplotlib.pyplot as plt

# Select the column corresponding to "On the Origin of Species" and 
v = sim_df["OriginofSpecies"]

# Sort by ascending scores
v_sorted = v.sort_values()

# Plot this data has a horizontal bar plot
# ... YOUR CODE FOR TASK 11 ...
v_sorted.plot.barh(x='lab', y='val', rot=0).plot

# Modify the axes labels and plot title for a better readability
# ... YOUR CODE FOR TASK 11 ...
plt.xlabel("Score")
plt.ylabel("Book Name")
plt.title("Similarity Score for Origin of Species")
# Out:
# Text(0.5, 1.0, 'Similarity Score for Origin of Species')

# %% [markdown]
# ## 12. Which books have similar content?
# <p>This turns out to be extremely useful if we want to determine a given book's most similar work. For example, we have just seen that if you enjoyed "<em>On the Origin of Species</em>," you can read books discussing similar concepts such as "<em>The Variation of Animals and Plants under Domestication</em>" or "<em>The Descent of Man, and Selection in Relation to Sex</em>." If you are familiar with Darwin's work, these suggestions will likely seem natural to you. Indeed, <em>On the Origin of Species</em> has a whole chapter about domestication and <em>The Descent of Man, and Selection in Relation to Sex</em> applies the theory of natural selection to human evolution. Hence, the results make sense.</p>
# <p>However, we now want to have a better understanding of the big picture and see how Darwin's books are generally related to each other (in terms of topics discussed). To this purpose, we will represent the whole similarity matrix as a dendrogram, which is a standard tool to display such data. <strong>This last approach will display all the information about book similarities at once.</strong> For example, we can find a book's closest relative but, also, we can visualize which groups of books have similar topics (e.g., the cluster about Charles Darwin personal life with his autobiography and letters). If you are familiar with Darwin's bibliography, the results should not surprise you too much, which indicates the method gives good results. Otherwise, next time you read one of the author's book, you will know which other books to read next in order to learn more about the topics it addressed.</p>

# %%
# Import libraries
from scipy.cluster import hierarchy

# Compute the clusters from the similarity matrix,
# using the Ward variance minimization algorithm
Z = hierarchy.linkage(sim_df, method='ward')

# Display this result as a horizontal dendrogram
# ... YOUR CODE FOR TASK 12 ...
hierarchy.dendrogram(Z, leaf_font_size=8, labels=sim_df.index, orientation="left")
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [45.0, 45.0, 60.0, 60.0],
#   [35.0, 35.0, 52.5, 52.5],
#   [75.0, 75.0, 85.0, 85.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [115.0, 115.0, 125.0, 125.0],
#   [100.0, 100.0, 120.0, 120.0],
#   [135.0, 135.0, 145.0, 145.0],
#   [155.0, 155.0, 165.0, 165.0],
#   [185.0, 185.0, 195.0, 195.0],
#   [175.0, 175.0, 190.0, 190.0],
#   [160.0, 160.0, 182.5, 182.5],
#   [140.0, 140.0, 171.25, 171.25],
#   [110.0, 110.0, 155.625, 155.625],
#   [80.0, 80.0, 132.8125, 132.8125],
#   [43.75, 43.75, 106.40625, 106.40625],
#   [12.5, 12.5, 75.078125, 75.078125]],
#  'dcoord': [[0.0, 0.26125293525233445, 0.26125293525233445, 0.0],
#   [0.0, 1.3180933156548695, 1.3180933156548695, 0.26125293525233445],
#   [0.0, 0.8694239045856135, 0.8694239045856135, 0.0],
#   [0.0, 1.138444590314043, 1.138444590314043, 0.8694239045856135],
#   [0.0, 1.2010735310998244, 1.2010735310998244, 1.138444590314043],
#   [0.0, 0.6850871755917214, 0.6850871755917214, 0.0],
#   [0.0, 0.8963453911940551, 0.8963453911940551, 0.0],
#   [0.0, 1.1051583965129728, 1.1051583965129728, 0.0],
#   [0.8963453911940551,
#    1.5290075431202388,
#    1.5290075431202388,
#    1.1051583965129728],
#   [0.0, 0.8620512119781137, 0.8620512119781137, 0.0],
#   [0.0, 1.0654180030092084, 1.0654180030092084, 0.0],
#   [0.0, 1.3654137461844351, 1.3654137461844351, 0.0],
#   [0.0, 1.4203366142591556, 1.4203366142591556, 1.3654137461844351],
#   [1.0654180030092084,
#    1.5485624680236296,
#    1.5485624680236296,
#    1.4203366142591556],
#   [0.8620512119781137,
#    1.8569886164134761,
#    1.8569886164134761,
#    1.5485624680236296],
#   [1.5290075431202388,
#    1.9969005608407535,
#    1.9969005608407535,
#    1.8569886164134761],
#   [0.6850871755917214,
#    2.079170443632404,
#    2.079170443632404,
#    1.9969005608407535],
#   [1.2010735310998244,
#    2.140972000686949,
#    2.140972000686949,
#    2.079170443632404],
#   [1.3180933156548695,
#    2.5512846547801598,
#    2.5512846547801598,
#    2.140972000686949]],
#  'ivl': ['Autobiography',
#   'LifeandLettersVol1',
#   'LifeandLettersVol2',
#   'DescentofMan',
#   'FoundationsOriginofSpecies',
#   'OriginofSpecies',
#   'VariationPlantsAnimalsDomestication',
#   'MonographCirripedia',
#   'MonographCirripediaVol2',
#   'GeologicalObservationsSouthAmerica',
#   'VolcanicIslands',
#   'CoralReefs',
#   'VoyageBeagle',
#   'DifferentFormsofFlowers',
#   'EffectsCrossSelfFertilization',
#   'InsectivorousPlants',
#   'MovementClimbingPlants',
#   'ExpressionofEmotionManAnimals',
#   'FormationVegetableMould',
#   'PowerMovementPlants'],
#  'leaves': [0,
#   10,
#   11,
#   2,
#   7,
#   15,
#   17,
#   12,
#   13,
#   8,
#   18,
#   1,
#   19,
#   3,
#   4,
#   9,
#   14,
#   5,
#   6,
#   16],
#  'color_list': ['C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C0',
#   'C0',
#   'C0',
#   'C0',
#   'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C3',
#   'C3',
#   'C4',
#   'C4',
#   'C4',
#   'C4',
#   'C5',
#   'C5',
#   'C6',
#   'C6',
#   'C6',
#   'C6',
#   'C6']}
